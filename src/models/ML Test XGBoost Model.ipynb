# %%
import pandas as pd
from datetime import datetime, date
from predict_model import PredictModel

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

model = PredictModel()

# Crée le dataframe de prédiction
df = model.create_dataframe(
    2023,
    8,
    "CONVERTED FLAT/MAISONETTE - UP TO 2 STOREYS",  # "AGRICULTURAL EQUIPMENT",
    "SW12",  # "BF1",
    "SST-EFFECTING ENTRY/EXIT",
    10,
    1,
)

display(df.head(10))

# model.apply_encoder(df, "TurnoutTimeSeconds")

result = model.predict(df)
display(pd.DataFrame( [result]))
# Out:
# Répertoire courant PredictModel: c:\Users\lordb\OneDrive\Documents\PTP\Projet IA\nov24_bds_pompiers\src\models
#   CalYear HourOfCall                                 PropertyType  \
# 0    2023          8  CONVERTED FLAT/MAISONETTE - UP TO 2 STOREYS
#
#   Postcode_district                  StopCode Month DayOfWeek
# 0              SW12  SST-EFFECTING ENTRY/EXIT    10         1
#   CalYear HourOfCall                                 PropertyType  \
# 0    2023          8  CONVERTED FLAT/MAISONETTE - UP TO 2 STOREYS
#
#   Postcode_district                  StopCode Month DayOfWeek
# 0              SW12  SST-EFFECTING ENTRY/EXIT    10         1
# Postcode_district
# PropertyType
# StopCode
#    CalYear  HourOfCall_0  HourOfCall_1  HourOfCall_2  HourOfCall_3  \
# 0       15             0             1             0             0
#
#    HourOfCall_4  Postcode_district_0  Postcode_district_1  \
# 0             1                    0                    0
#
# ...
