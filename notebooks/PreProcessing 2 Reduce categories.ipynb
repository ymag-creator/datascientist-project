# %%
# ------------------------- Préparation des informations de réduction des valeurs catégorielles -----------------------------

import pandas as pd
import statsmodels.api
from statsmodels.api import stats
import statsmodels.formula.api as smf

# Ajuster les paramètres pour afficher toutes les lignes et colonnes
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
def load_incidents():
    """
    Charge le dataset sauvegardé 'Preprocess.csv' contenant le merge prétraités des données des incidents et mobilisations.

    Cette fonction effectue les opérations suivantes :
    - Charge le datasets à partir du fichier CSV.
    - Affiche  les premieres lignes
    - Affiche les infos du dataset
    
    Returns:
        pd.DataFrame: Le DataFrame contenant les données des incidents et mobilisations.
    """
    #charge le dataset
    df = pd.read_csv("../data/PreProcess.csv", sep=";", low_memory=False)
    #affiche les premieres lignes et infos du dataframe
    display(df.head())
    display(df.info())
    return df

# %%
# Traitment des catégories StopCode, PropertyType, Postcode_district
# Pour conserver les valeurs catégorielles en fonction d'un 
# Test de Anova, pour chacune des cibles

cols_cible_type = ["PumpSecondsOnSite", "TurnoutTimeSeconds", "TravelTimeSeconds"]

def calc_anova_for_all_targets(df):
    """
    Calcule les tests ANOVA pour toutes les cibles spécifiées dans le DataFrame fourni.

    Cette fonction effectue les opérations suivantes :
    - Définit les colonnes catégorielles et les colonnes cibles à analyser.
        ["PumpSecondsOnSite_min", "PumpSecondsOnSite_mean", "PumpSecondsOnSite_max"],
        ["TurnoutTimeSeconds_min", "TurnoutTimeSeconds_mean", "TurnoutTimeSeconds_max"],
        ["TravelTimeSeconds_min", "TravelTimeSeconds_mean", "TravelTimeSeconds_max"],
    - Affiche le nombre de valeurs uniques pour chaque colonne catégorielle.
    - Filtre les données pour inclure uniquement les années après 2016 afin de réduire le temps de calcul.
    - Effectue des tests ANOVA pour chaque colonne cible avec toutes les colonnes catégorielles.
    - Crée un DataFrame des résultats avec les coefficients et les p-values.
    - Affiche les résultats des tests ANOVA.
    - Fusionne les résultats dans un DataFrame compilé par type de cible.

    Args:
        df (pd.DataFrame): Le DataFrame contenant les données à analyser.

    Returns:
        list: Une liste de DataFrames compilés contenant les résultats des tests ANOVA pour chaque type de cible.
    """


    # Catégories
    cols_categ = [
        "StopCode",
        "PropertyType",
        "Postcode_district",
    ]
    # Cibles à caluler
    cols_cible = [
        ["PumpSecondsOnSite_min", "PumpSecondsOnSite_mean", "PumpSecondsOnSite_max"],
        ["TurnoutTimeSeconds_min", "TurnoutTimeSeconds_mean", "TurnoutTimeSeconds_max"],
        ["TravelTimeSeconds_min", "TravelTimeSeconds_mean", "TravelTimeSeconds_max"],
    ]

    # Nb de valeurs actuelles par catégories
    for col in cols_categ:
        print(col, len(df[col].unique()))
    print()

    # Test de Anova sur les données après 2016, pour réduire le temps de calcul
    df_temp = df[df.CalYear.astype("int") > 2016]

    # Test de Anova sur chaque colonne cible avec toutes les colonnes catégorielles
    all_result = []
    # Formatage des colonnes catégorielles pour le test de Anova
    cols_to_check = "+".join(cols_categ)
    # Pour chaque tableau, par type de cible 
    # (exemple PumpSecondsOnSite, calcul pour min, mean, max)
    for cols in cols_cible:
        cible_results = []
        # Pour chaque valeur à calculer (min, max, mean)
        for col in cols:
            print("Test de", col)
            # Test de Anova pour une cible, par exemple PumpSecondsOnSite_min
            results = smf.ols(f"{col} ~ {cols_to_check}", data=df_temp).fit()
            # table = stats.anova_lm(result)
            # display(table)
            # Création d'un Dataframe du résultat avec le coefficient et la pvalue
            results_df = pd.DataFrame(
                {
                    f"{col} coefficients": round(results.params, 3),
                    f"{col} pvalues": round(results.pvalues, 3),
                }
            )
            # Ajoute le résultat au tableau par type de cible
            cible_results.append(results_df)
            # display(results_df)
            # print("Test de", col, "ok")
        # Ajoute le résultat par type de cible aux résultats globaux
        all_result.append(cible_results)

    # Contrôle
    for cible_results in all_result:
        for result in cible_results:
            display(result.head())

    # Merge les resultats dans un dataFrame, en gardant un Dataframe par type de cible
    # et en mettant les résultats pvalue et codef par min, mean et max en colonne
    compiled_results = []
    for cible_results in all_result:
        cible_result = cible_results[0]
        i = 0
        for result in cible_results:
            if i == 0:
                print("continue")
                i += 1
                continue
            print("merge")
            cible_result = pd.merge(
                cible_result, result, left_index=True, right_index=True, how="outer"
            )
        compiled_results.append(cible_result)

    return compiled_results



def calculate_keeps_by_target(compiled_results):
    
     """
     Ajoute 2 colonnes Discord et Keep dans les dataframes pour finaliser le choix
     
     des valeurs catégorielles à conserver dans la liste de DataFrame fourni.  

    Args:
        df (pd.DataFrame): Une liste de DataFrames compilés contenant les résultats des tests ANOVA pour chaque type de cible.

    Returns:
        list: Une liste de DataFrames compilés contenant les valeurs catégorielles à conserver.
    """
     
    print("Calcule Discords")


   
    def TreatDiscordRow(columns, row):
     """
    Détermine si les p-values dans une ligne donnée sont uniformes ou discordantes.

    Cette fonction effectue les opérations suivantes :
    - Crée une liste de booléens indiquant si les p-values sont inférieures ou égales à 0.05.
    - Calcule la somme des booléens pour déterminer si toutes les p-values sont uniformes (toutes significatives ou toutes non significatives).
    - Retourne True si les p-values sont discordantes (c'est-à-dire, certaines sont significatives et d'autres non), sinon retourne False.

    Args:
        columns (list): La liste des noms de colonnes du DataFrame.
        row (pd.Series): Une ligne du DataFrame contenant les p-values à vérifier.

    Returns:
        bool: True si les p-values sont discordantes, sinon False.
    """
        keeps = []
        nb = 0

        for i in range(1, len(columns), 2):
            # print("col", columns[i])
            # print(row)
            # Crée un tableau à 3 boolean qui indique si <= 0.05 ou non 
            keeps.append(row[columns[i]] <= 0.05)
            nb += 1
        # Somme des 3 boolean, si le résultat donne 3 ou 0 alors les 3 pvalue
        # sont uniformes, sinon non, donc Discord
        val = not (sum(keeps) == 0) | (sum(keeps) == nb)  # sum(keeps)
        # print(val)
        return val

    
    def TreatKeepRow(columns, row):
        """
    Détermine si une ligne doit être conservée en fonction des p-values.

    Cette fonction effectue les opérations suivantes :
    - Vérifie si toutes les p-values sont significatives (<= 0.05) ou non significatives (> 0.05).
    - Si toutes les p-values sont non significatives, la ligne n'est pas conservée.
    - Si toutes les p-values sont significatives, la ligne est conservée.
    - Sinon, la ligne est conservée si la p-value de la moyenne ou du maximum est significative.
    
    Args:
        columns (list): Liste des colonnes du DataFrame.
        row (pd.Series): Ligne du DataFrame à vérifier.

    Returns:
        bool: True si la ligne doit être conservée, False sinon.
    """ 
  
        keeps = []
        nb = 0
        for i in range(1, len(columns), 2):
            # print("col", columns[i])
            # print(row[columns[i]])
            keeps.append(row[columns[i]] <= 0.05)
            nb += 1
        val = sum(keeps)
        # si toutes les pvalues sont non significatives
        if val == 0:
            return False
        # si toutes les pvalues sont significatives
        elif val == nb:
            return True
        # sinon, conserve si c'est significatif sur la moyenne ou max
        else:

            mean_col = [s for s in columns if "mean pvalues" in s][0]
            max_col = [s for s in columns if "max pvalues" in s][0]            
            mean = row[mean_col]
            max = row[max_col]
            keep = True if (mean <= 0.05) | (max <= 0.05) else False
            print(mean_col, mean, max_col, max, keep)
            # print("mean_col", mean_col)
            # print("mean_col", val)
            return keep

    # Pour chaque type de cible (ex : PumpSecondsOnSite) on a un DF avec les 
    # pvalue par cible min, max, mean et une ligne par valeur de catégorie
    for cible_results in compiled_results:
        # display(cible_results.head())
        # Ajout d'une colonne Discord qui indique si les pvalue sont toutes
        # <0.05 ou > 0.05, donc un Keep évident
        cible_results["Discord"] = cible_results.apply(
            lambda row: TreatDiscordRow(cible_results.columns, row), axis=1
        )
        # Calcul si on garde ou non la valeur catégorielle pour un type de cible
        cible_results["Keep"] = cible_results.apply(
            lambda row: TreatKeepRow(cible_results.columns, row), axis=1
        )
        # Contrôle
        display(cible_results[cible_results.Discord == True].head())
    # Résumé des données conserver par type de cible
    for i in range(0, len(compiled_results)):
        print(
            f"{cols_cible_type[i]} {compiled_results[i]["Discord"].sum()} discords, {compiled_results[i]["Keep"].sum()} keeps, sur {len(compiled_results[i])}, "
            f"conserve {round(compiled_results[i]["Keep"].sum() / len(compiled_results[i]) * 100, 0)}%"
        )
    return compiled_results

# %%
 
def save_categorical_reduction(compiled_results):
     """
    Sauvegarde les informations des valeurs catégorielles après réduction dans des fichiers CSV.

    Cette fonction effectue les opérations suivantes :
    - Conserve uniquement les valeurs catégorielles marquées comme "Keep" dans les résultats compilés.
    - Supprime la ligne "Intercept" des résultats.
    - Crée deux colonnes, "Column" et "Value", à partir de l'index des résultats.
    - Sauvegarde les DataFrames résultants dans des fichiers CSV.

    Args:
        compiled_results (list): Une liste de DataFrames contenant les résultats compilés des tests ANOVA.
    """
     
    def SplitCatValue(s, return_name):
        """
    Sépare une chaîne de caractères en deux parties et retourne l'une des parties en fonction du paramètre `return_name`.

    Cette fonction effectue les opérations suivantes :
    - Sépare la chaîne de caractères `s` en deux parties en utilisant le caractère '[' comme séparateur.
    - Retourne la première partie si `return_name` est True.
    - Retourne la deuxième partie, sans les deux premiers et le dernier caractère, si `return_name` est False.

    Args:
        s (str): La chaîne de caractères à séparer.
        return_name (bool): Un booléen indiquant quelle partie de la chaîne doit être retournée.

    Returns:
        str: La partie de la chaîne de caractères spécifiée par `return_name`.
    """
        result = s.split("[")
        return result[0] if return_name else result[1][2:-1]

    # Sauve les infos des valeurs catégorielles
    for i in range(0, len(compiled_results)):
        # Conserve uniquement la valeur Keep, qui est le résultat final
        # L'index étant la valeur catégorielle
        df_to_save = compiled_results[i][["Keep"]]
        # supprime la ligne Intercept
        df_to_save = df_to_save.drop(
            df_to_save[df_to_save.index.str.upper() == "INTERCEPT"].index
        )
        # Les valeurs de df_keep ont le format
        #           AddressQualifier[T.IN STREET CLOSE TO GAZETTEER LOCATION]	True (colonne Keep)
        # Crée 2 colonnes, nom de colonne et valeur
        # Prend l'index
        df_to_save["Column"] = df_to_save.index
        # Split l'index et retourne la 1ere partie qui est le nom de la catégorie
        df_to_save["Column"] = df_to_save["Column"].apply(lambda s: SplitCatValue(s, True))
        df_to_save["Value"] = df_to_save.index
        # Split l'index et retourne la 2eme partie qui est la valeur catégorielle
        df_to_save["Value"] = df_to_save["Value"].apply(lambda s: SplitCatValue(s, False))
        display(df_to_save.head(10))
        # Sauvegarde le DF dans un fichier
        name = f"keep {cols_cible_type[i]}"
        print(name)
        df_to_save.to_csv(f"../data/{name}.csv", sep=";", index=False)

# %%
df = load_incidents()
compiled_results = calc_anova_for_all_targets(df)
compiled_results = calculate_keeps_by_target(compiled_results)
save_categorical_reduction(compiled_results)
# 10 minutes
# Out:
#   IncidentNumber  CalYear  HourOfCall  \
# 0      235138081     2009           0
# 1           2091     2009           0
# 2           3091     2009           0
# 3           5091     2009           0
# 4           6091     2009           0
#
#                                         PropertyType Postcode_district  \
# 0                                                CAR              SW11
# 1                              ROAD SURFACE/PAVEMENT                N9
# 2         DOMESTIC GARDEN (VEGETATION NOT EQUIPMENT)              UB10
# 3               CYCLE PATH/PUBLIC FOOTPATH/BRIDLEWAY                N7
# 4  PURPOSE BUILT FLATS/MAISONETTES - UP TO 3 STOREYS               NW5
#
#    NumPumpsAttending        StopCode  Month  DayOfWeek  PumpSecondsOnSite_min  \
# 0                2.0         SST-RTC      1          4                  240.0
# 1                1.0  SECONDARY FIRE      1          4                  420.0
# 2                1.0  SECONDARY FIRE      1          4                  720.0
# 3                2.0  SECONDARY FIRE      1          4                  120.0
# 4                2.0           ALARM      1          4                  360.0
#
#    PumpSecondsOnSite_mean  PumpSecondsOnSite_max  TurnoutTimeSeconds_min  \
# 0                   390.0                  540.0                   253.0
# 1                   420.0                  420.0                   151.0
# 2                   720.0                  720.0                   108.0
# 3                   120.0                  120.0                   114.0
# 4                   360.0                  360.0                    83.0
#
#    TurnoutTimeSeconds_mean  TurnoutTimeSeconds_max  TravelTimeSeconds_min  \
# 0                    253.0                   253.0                   89.0
# 1                    151.0                   151.0                  157.0
# 2                    108.0                   108.0                  102.0
# 3                    128.0                   142.0                  108.0
# 4                     89.0                    95.0                   89.0
#
#    TravelTimeSeconds_mean  TravelTimeSeconds_max
# 0                    89.0                   89.0
# 1                   157.0                  157.0
# 2                   102.0                  102.0
# 3                   113.5                  119.0
# 4                   108.0                  127.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591527 entries, 0 to 1591526
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   IncidentNumber           1591527 non-null  object
#  1   CalYear                  1591527 non-null  int64
#  2   HourOfCall               1591527 non-null  int64
#  3   PropertyType             1591527 non-null  object
#  4   Postcode_district        1591527 non-null  object
#  5   NumPumpsAttending        1591527 non-null  float64
#  6   StopCode                 1591527 non-null  object
#  7   Month                    1591527 non-null  int64
#  8   DayOfWeek                1591527 non-null  int64
#  9   PumpSecondsOnSite_min    1591527 non-null  float64
#  10  PumpSecondsOnSite_mean   1591527 non-null  float64
#  11  PumpSecondsOnSite_max    1591527 non-null  float64
#  12  TurnoutTimeSeconds_min   1591527 non-null  float64
#  13  TurnoutTimeSeconds_mean  1591527 non-null  float64
#  14  TurnoutTimeSeconds_max   1591527 non-null  float64
#  15  TravelTimeSeconds_min    1591527 non-null  float64
#  16  TravelTimeSeconds_mean   1591527 non-null  float64
#  17  TravelTimeSeconds_max    1591527 non-null  float64
# dtypes: float64(10), int64(4), object(4)
# memory usage: 218.6+ MB
# None
# StopCode 26
# PropertyType 292
# Postcode_district 324
#
# Test de PumpSecondsOnSite_min
# Test de PumpSecondsOnSite_mean
# Test de PumpSecondsOnSite_max
# Test de TurnoutTimeSeconds_min
# Test de TurnoutTimeSeconds_mean
# Test de TurnoutTimeSeconds_max
# Test de TravelTimeSeconds_min
# Test de TravelTimeSeconds_mean
# Test de TravelTimeSeconds_max
#                             PumpSecondsOnSite_min coefficients  \
# Intercept                                              812.586
# StopCode[T.CHIMNEY FIRE]                              2856.532
# StopCode[T.LATE CALL]                                 1230.093
# StopCode[T.PRIMARY FIRE]                              1551.532
# StopCode[T.SECONDARY FIRE]                             443.792
#
#                             PumpSecondsOnSite_min pvalues
# Intercept                                            0.19
# StopCode[T.CHIMNEY FIRE]                             0.00
# StopCode[T.LATE CALL]                                0.00
# StopCode[T.PRIMARY FIRE]                             0.00
# StopCode[T.SECONDARY FIRE]                           0.00
#                             PumpSecondsOnSite_mean coefficients  \
# Intercept                                               781.555
# StopCode[T.CHIMNEY FIRE]                               3025.469
# StopCode[T.LATE CALL]                                  1139.469
# StopCode[T.PRIMARY FIRE]                               2029.010
# StopCode[T.SECONDARY FIRE]                              448.303
#
#                             PumpSecondsOnSite_mean pvalues
# Intercept                                            0.229
# StopCode[T.CHIMNEY FIRE]                             0.000
# StopCode[T.LATE CALL]                                0.000
# StopCode[T.PRIMARY FIRE]                             0.000
# StopCode[T.SECONDARY FIRE]                           0.000
#                             PumpSecondsOnSite_max coefficients  \
# Intercept                                              351.056
# StopCode[T.CHIMNEY FIRE]                              3141.756
# StopCode[T.LATE CALL]                                 1013.849
# StopCode[T.PRIMARY FIRE]                              2652.239
# StopCode[T.SECONDARY FIRE]                             447.871
#
#                             PumpSecondsOnSite_max pvalues
# Intercept                                           0.631
# StopCode[T.CHIMNEY FIRE]                            0.000
# StopCode[T.LATE CALL]                               0.000
# StopCode[T.PRIMARY FIRE]                            0.000
# StopCode[T.SECONDARY FIRE]                          0.000
#                             TurnoutTimeSeconds_min coefficients  \
# Intercept                                                87.712
# StopCode[T.CHIMNEY FIRE]                                  1.926
# StopCode[T.LATE CALL]                                    16.018
# StopCode[T.PRIMARY FIRE]                                 -2.037
# StopCode[T.SECONDARY FIRE]                                4.272
#
#                             TurnoutTimeSeconds_min pvalues
# Intercept                                            0.000
# StopCode[T.CHIMNEY FIRE]                             0.516
# StopCode[T.LATE CALL]                                0.004
# StopCode[T.PRIMARY FIRE]                             0.000
# StopCode[T.SECONDARY FIRE]                           0.000
#                             TurnoutTimeSeconds_mean coefficients  \
# Intercept                                                101.868
# StopCode[T.CHIMNEY FIRE]                                   1.191
# StopCode[T.LATE CALL]                                      5.858
# StopCode[T.PRIMARY FIRE]                                   0.498
# StopCode[T.SECONDARY FIRE]                                 0.444
#
#                             TurnoutTimeSeconds_mean pvalues
# Intercept                                             0.000
# StopCode[T.CHIMNEY FIRE]                              0.692
# StopCode[T.LATE CALL]                                 0.304
# StopCode[T.PRIMARY FIRE]                              0.002
# StopCode[T.SECONDARY FIRE]                            0.125
#                             TurnoutTimeSeconds_max coefficients  \
# Intercept                                               122.609
# StopCode[T.CHIMNEY FIRE]                                 -0.894
# StopCode[T.LATE CALL]                                    -5.748
# StopCode[T.PRIMARY FIRE]                                  4.006
# StopCode[T.SECONDARY FIRE]                               -3.949
#
#                             TurnoutTimeSeconds_max pvalues
# Intercept                                            0.000
# StopCode[T.CHIMNEY FIRE]                             0.804
# StopCode[T.LATE CALL]                                0.399
# StopCode[T.PRIMARY FIRE]                             0.000
# StopCode[T.SECONDARY FIRE]                           0.000
#                             TravelTimeSeconds_min coefficients  \
# Intercept                                              451.722
# StopCode[T.CHIMNEY FIRE]                                -1.700
# StopCode[T.LATE CALL]                                   34.892
# StopCode[T.PRIMARY FIRE]                                -7.928
# StopCode[T.SECONDARY FIRE]                             -11.341
#
#                             TravelTimeSeconds_min pvalues
# Intercept                                           0.000
# StopCode[T.CHIMNEY FIRE]                            0.866
# StopCode[T.LATE CALL]                               0.068
# StopCode[T.PRIMARY FIRE]                            0.000
# StopCode[T.SECONDARY FIRE]                          0.000
#                             TravelTimeSeconds_mean coefficients  \
# Intercept                                               512.153
# StopCode[T.CHIMNEY FIRE]                                 -6.288
# StopCode[T.LATE CALL]                                    -6.697
# StopCode[T.PRIMARY FIRE]                                  6.532
# StopCode[T.SECONDARY FIRE]                              -26.229
#
#                             TravelTimeSeconds_mean pvalues
# Intercept                                            0.000
# StopCode[T.CHIMNEY FIRE]                             0.547
# StopCode[T.LATE CALL]                                0.735
# StopCode[T.PRIMARY FIRE]                             0.000
# StopCode[T.SECONDARY FIRE]                           0.000
#                             TravelTimeSeconds_max coefficients  \
# Intercept                                              556.895
# StopCode[T.CHIMNEY FIRE]                               -11.411
# StopCode[T.LATE CALL]                                  -49.299
# StopCode[T.PRIMARY FIRE]                                24.055
# StopCode[T.SECONDARY FIRE]                             -41.506
#
#                             TravelTimeSeconds_max pvalues
# Intercept                                           0.000
# StopCode[T.CHIMNEY FIRE]                            0.348
# StopCode[T.LATE CALL]                               0.032
# StopCode[T.PRIMARY FIRE]                            0.000
# StopCode[T.SECONDARY FIRE]                          0.000
# continue
# merge
# merge
# continue
# merge
# merge
# continue
# merge
# merge
# Calcule Discords
# PumpSecondsOnSite_mean pvalues 0.051 PumpSecondsOnSite_max pvalues 0.027 True
# PumpSecondsOnSite_mean pvalues 0.107 PumpSecondsOnSite_max pvalues 0.141 False
# PumpSecondsOnSite_mean pvalues 0.067 PumpSecondsOnSite_max pvalues 0.046 True
# PumpSecondsOnSite_mean pvalues 0.074 PumpSecondsOnSite_max pvalues 0.673 False
# PumpSecondsOnSite_mean pvalues 0.079 PumpSecondsOnSite_max pvalues 0.423 False
# PumpSecondsOnSite_mean pvalues 0.25 PumpSecondsOnSite_max pvalues 0.015 True
# PumpSecondsOnSite_mean pvalues 0.071 PumpSecondsOnSite_max pvalues 0.508 False
# PumpSecondsOnSite_mean pvalues 0.174 PumpSecondsOnSite_max pvalues 0.865 False
# PumpSecondsOnSite_mean pvalues 0.099 PumpSecondsOnSite_max pvalues 0.533 False
# PumpSecondsOnSite_mean pvalues 0.112 PumpSecondsOnSite_max pvalues 0.561 False
# PumpSecondsOnSite_mean pvalues 0.225 PumpSecondsOnSite_max pvalues 0.957 False
# PumpSecondsOnSite_mean pvalues 0.151 PumpSecondsOnSite_max pvalues 0.551 False
# PumpSecondsOnSite_mean pvalues 0.06 PumpSecondsOnSite_max pvalues 0.206 False
# PumpSecondsOnSite_mean pvalues 0.046 PumpSecondsOnSite_max pvalues 0.086 True
# PumpSecondsOnSite_mean pvalues 0.018 PumpSecondsOnSite_max pvalues 0.054 True
# PumpSecondsOnSite_mean pvalues 0.187 PumpSecondsOnSite_max pvalues 0.648 False
# PumpSecondsOnSite_mean pvalues 0.049 PumpSecondsOnSite_max pvalues 0.366 True
# PumpSecondsOnSite_mean pvalues 0.064 PumpSecondsOnSite_max pvalues 0.451 False
# PumpSecondsOnSite_mean pvalues 0.034 PumpSecondsOnSite_max pvalues 0.314 True
# PumpSecondsOnSite_mean pvalues 0.194 PumpSecondsOnSite_max pvalues 0.69 False
# PumpSecondsOnSite_mean pvalues 0.101 PumpSecondsOnSite_max pvalues 0.416 False
# PumpSecondsOnSite_mean pvalues 0.046 PumpSecondsOnSite_max pvalues 0.409 True
# PumpSecondsOnSite_mean pvalues 0.15 PumpSecondsOnSite_max pvalues 0.808 False
# PumpSecondsOnSite_mean pvalues 0.18 PumpSecondsOnSite_max pvalues 0.675 False
# PumpSecondsOnSite_mean pvalues 0.154 PumpSecondsOnSite_max pvalues 0.593 False
# PumpSecondsOnSite_mean pvalues 0.025 PumpSecondsOnSite_max pvalues 0.108 True
# PumpSecondsOnSite_mean pvalues 0.098 PumpSecondsOnSite_max pvalues 0.463 False
# PumpSecondsOnSite_mean pvalues 0.081 PumpSecondsOnSite_max pvalues 0.449 False
# PumpSecondsOnSite_mean pvalues 0.054 PumpSecondsOnSite_max pvalues 0.009 True
# PumpSecondsOnSite_mean pvalues 0.256 PumpSecondsOnSite_max pvalues 0.857 False
# PumpSecondsOnSite_mean pvalues 0.204 PumpSecondsOnSite_max pvalues 0.734 False
# PumpSecondsOnSite_mean pvalues 0.197 PumpSecondsOnSite_max pvalues 0.748 False
# PumpSecondsOnSite_mean pvalues 0.055 PumpSecondsOnSite_max pvalues 0.35 False
# PumpSecondsOnSite_mean pvalues 0.023 PumpSecondsOnSite_max pvalues 0.124 True
# PumpSecondsOnSite_mean pvalues 0.089 PumpSecondsOnSite_max pvalues 0.027 True
# PumpSecondsOnSite_mean pvalues 0.159 PumpSecondsOnSite_max pvalues 0.511 False
# PumpSecondsOnSite_mean pvalues 0.269 PumpSecondsOnSite_max pvalues 0.963 False
# PumpSecondsOnSite_mean pvalues 0.166 PumpSecondsOnSite_max pvalues 0.595 False
# PumpSecondsOnSite_mean pvalues 0.08 PumpSecondsOnSite_max pvalues 0.619 False
# PumpSecondsOnSite_mean pvalues 0.069 PumpSecondsOnSite_max pvalues 0.508 False
# PumpSecondsOnSite_mean pvalues 0.072 PumpSecondsOnSite_max pvalues 0.505 False
# PumpSecondsOnSite_mean pvalues 0.272 PumpSecondsOnSite_max pvalues 0.881 False
# PumpSecondsOnSite_mean pvalues 0.109 PumpSecondsOnSite_max pvalues 0.002 True
# PumpSecondsOnSite_mean pvalues 0.151 PumpSecondsOnSite_max pvalues 0.85 False
# PumpSecondsOnSite_mean pvalues 0.17 PumpSecondsOnSite_max pvalues 0.0 True
# PumpSecondsOnSite_mean pvalues 0.133 PumpSecondsOnSite_max pvalues 0.577 False
# PumpSecondsOnSite_mean pvalues 0.314 PumpSecondsOnSite_max pvalues 0.026 True
# PumpSecondsOnSite_mean pvalues 0.157 PumpSecondsOnSite_max pvalues 0.561 False
# PumpSecondsOnSite_mean pvalues 0.27 PumpSecondsOnSite_max pvalues 0.874 False
# PumpSecondsOnSite_mean pvalues 0.071 PumpSecondsOnSite_max pvalues 0.544 False
# PumpSecondsOnSite_mean pvalues 0.066 PumpSecondsOnSite_max pvalues 0.571 False
# PumpSecondsOnSite_mean pvalues 0.067 PumpSecondsOnSite_max pvalues 0.4 False
# PumpSecondsOnSite_mean pvalues 0.146 PumpSecondsOnSite_max pvalues 0.555 False
# PumpSecondsOnSite_mean pvalues 0.128 PumpSecondsOnSite_max pvalues 0.434 False
# PumpSecondsOnSite_mean pvalues 0.073 PumpSecondsOnSite_max pvalues 0.013 True
# PumpSecondsOnSite_mean pvalues 0.076 PumpSecondsOnSite_max pvalues 0.602 False
# PumpSecondsOnSite_mean pvalues 0.068 PumpSecondsOnSite_max pvalues 0.506 False
# PumpSecondsOnSite_mean pvalues 0.009 PumpSecondsOnSite_max pvalues 0.063 True
# PumpSecondsOnSite_mean pvalues 0.221 PumpSecondsOnSite_max pvalues 0.029 True
# PumpSecondsOnSite_mean pvalues 0.053 PumpSecondsOnSite_max pvalues 0.361 False
# PumpSecondsOnSite_mean pvalues 0.318 PumpSecondsOnSite_max pvalues 0.034 True
# PumpSecondsOnSite_mean pvalues 0.518 PumpSecondsOnSite_max pvalues 0.006 True
# PumpSecondsOnSite_mean pvalues 0.15 PumpSecondsOnSite_max pvalues 0.553 False
# PumpSecondsOnSite_mean pvalues 0.185 PumpSecondsOnSite_max pvalues 0.632 False
# PumpSecondsOnSite_mean pvalues 0.224 PumpSecondsOnSite_max pvalues 0.726 False
# PumpSecondsOnSite_mean pvalues 0.199 PumpSecondsOnSite_max pvalues 0.961 False
# PumpSecondsOnSite_mean pvalues 0.034 PumpSecondsOnSite_max pvalues 0.078 True
# PumpSecondsOnSite_mean pvalues 0.043 PumpSecondsOnSite_max pvalues 0.071 True
# PumpSecondsOnSite_mean pvalues 0.34 PumpSecondsOnSite_max pvalues 0.006 True
# PumpSecondsOnSite_mean pvalues 0.089 PumpSecondsOnSite_max pvalues 0.449 False
# PumpSecondsOnSite_mean pvalues 0.067 PumpSecondsOnSite_max pvalues 0.639 False
# PumpSecondsOnSite_mean pvalues 0.024 PumpSecondsOnSite_max pvalues 0.002 True
# PumpSecondsOnSite_mean pvalues 0.067 PumpSecondsOnSite_max pvalues 0.372 False
# PumpSecondsOnSite_mean pvalues 0.042 PumpSecondsOnSite_max pvalues 0.293 True
# PumpSecondsOnSite_mean pvalues 0.193 PumpSecondsOnSite_max pvalues 0.674 False
# PumpSecondsOnSite_mean pvalues 0.138 PumpSecondsOnSite_max pvalues 0.551 False
# PumpSecondsOnSite_mean pvalues 0.048 PumpSecondsOnSite_max pvalues 0.02 True
# PumpSecondsOnSite_mean pvalues 0.009 PumpSecondsOnSite_max pvalues 0.114 True
# PumpSecondsOnSite_mean pvalues 0.18 PumpSecondsOnSite_max pvalues 0.692 False
# PumpSecondsOnSite_mean pvalues 0.135 PumpSecondsOnSite_max pvalues 0.874 False
# PumpSecondsOnSite_mean pvalues 0.081 PumpSecondsOnSite_max pvalues 0.566 False
# PumpSecondsOnSite_mean pvalues 0.216 PumpSecondsOnSite_max pvalues 0.737 False
# PumpSecondsOnSite_mean pvalues 0.027 PumpSecondsOnSite_max pvalues 0.27 True
# PumpSecondsOnSite_mean pvalues 0.097 PumpSecondsOnSite_max pvalues 0.021 True
# PumpSecondsOnSite_mean pvalues 0.05 PumpSecondsOnSite_max pvalues 0.008 True
# PumpSecondsOnSite_mean pvalues 0.057 PumpSecondsOnSite_max pvalues 0.468 False
# PumpSecondsOnSite_mean pvalues 0.031 PumpSecondsOnSite_max pvalues 0.223 True
# PumpSecondsOnSite_mean pvalues 0.062 PumpSecondsOnSite_max pvalues 0.491 False
# PumpSecondsOnSite_mean pvalues 0.041 PumpSecondsOnSite_max pvalues 0.143 True
# PumpSecondsOnSite_mean pvalues 0.229 PumpSecondsOnSite_max pvalues 0.791 False
# PumpSecondsOnSite_mean pvalues 0.003 PumpSecondsOnSite_max pvalues 0.052 True
# PumpSecondsOnSite_mean pvalues 0.198 PumpSecondsOnSite_max pvalues 0.697 False
# PumpSecondsOnSite_mean pvalues 0.076 PumpSecondsOnSite_max pvalues 0.636 False
# PumpSecondsOnSite_mean pvalues 0.19 PumpSecondsOnSite_max pvalues 0.635 False
# PumpSecondsOnSite_mean pvalues 0.141 PumpSecondsOnSite_max pvalues 0.611 False
# PumpSecondsOnSite_mean pvalues 0.118 PumpSecondsOnSite_max pvalues 0.019 True
# PumpSecondsOnSite_mean pvalues 0.022 PumpSecondsOnSite_max pvalues 0.079 True
# PumpSecondsOnSite_mean pvalues 0.115 PumpSecondsOnSite_max pvalues 0.507 False
# PumpSecondsOnSite_mean pvalues 0.253 PumpSecondsOnSite_max pvalues 0.909 False
# PumpSecondsOnSite_mean pvalues 0.08 PumpSecondsOnSite_max pvalues 0.001 True
# PumpSecondsOnSite_mean pvalues 0.095 PumpSecondsOnSite_max pvalues 0.001 True
# PumpSecondsOnSite_mean pvalues 0.027 PumpSecondsOnSite_max pvalues 0.055 True
# PumpSecondsOnSite_mean pvalues 0.103 PumpSecondsOnSite_max pvalues 0.018 True
# PumpSecondsOnSite_mean pvalues 0.138 PumpSecondsOnSite_max pvalues 0.548 False
# PumpSecondsOnSite_mean pvalues 0.007 PumpSecondsOnSite_max pvalues 0.084 True
# PumpSecondsOnSite_mean pvalues 0.064 PumpSecondsOnSite_max pvalues 0.446 False
#                                  PumpSecondsOnSite_min coefficients  \
# Postcode_district[T.CR6]                                   1162.606
# Postcode_district[T.KT22]                                  1420.584
# Postcode_district[T.TN14]                                  1099.578
# PropertyType[T.AIRFIELD/RUNWAY]                           -1030.825
# PropertyType[T.BARBECUE]                                   -882.688
#
#                                  PumpSecondsOnSite_min pvalues  \
# Postcode_district[T.CR6]                                 0.034
# Postcode_district[T.KT22]                                0.036
# Postcode_district[T.TN14]                                0.041
# PropertyType[T.AIRFIELD/RUNWAY]                          0.009
# PropertyType[T.BARBECUE]                                 0.012
#
#                                  PumpSecondsOnSite_mean coefficients  \
# Postcode_district[T.CR6]                                    1120.016
# Postcode_district[T.KT22]                                   1144.002
# Postcode_district[T.TN14]                                   1030.426
# PropertyType[T.AIRFIELD/RUNWAY]                             -739.040
# PropertyType[T.BARBECUE]                                    -646.260
#
#                                  PumpSecondsOnSite_mean pvalues  \
# Postcode_district[T.CR6]                                  0.051
# Postcode_district[T.KT22]                                 0.107
# Postcode_district[T.TN14]                                 0.067
# PropertyType[T.AIRFIELD/RUNWAY]                           0.074
# PropertyType[T.BARBECUE]                                  0.079
#
#                                  PumpSecondsOnSite_max coefficients  \
# Postcode_district[T.CR6]                                   1426.907
# Postcode_district[T.KT22]                                  1177.248
# Postcode_district[T.TN14]                                  1268.336
# PropertyType[T.AIRFIELD/RUNWAY]                             197.090
# PropertyType[T.BARBECUE]                                   -331.870
#
#                                  PumpSecondsOnSite_max pvalues  Discord   Keep
# Postcode_district[T.CR6]                                 0.027     True   True
# Postcode_district[T.KT22]                                0.141     True  False
# Postcode_district[T.TN14]                                0.046     True   True
# PropertyType[T.AIRFIELD/RUNWAY]                          0.673     True  False
# PropertyType[T.BARBECUE]                                 0.423     True  False
# TurnoutTimeSeconds_mean pvalues 0.011 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.053 TurnoutTimeSeconds_max pvalues 0.025 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.041 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.046 TurnoutTimeSeconds_max pvalues 0.01 True
# TurnoutTimeSeconds_mean pvalues 0.031 TurnoutTimeSeconds_max pvalues 0.005 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.017 TurnoutTimeSeconds_max pvalues 0.006 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.021 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.003 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.071 TurnoutTimeSeconds_max pvalues 0.024 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.034 TurnoutTimeSeconds_max pvalues 0.019 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.01 TurnoutTimeSeconds_max pvalues 0.01 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.093 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.108 TurnoutTimeSeconds_max pvalues 0.042 True
# TurnoutTimeSeconds_mean pvalues 0.053 TurnoutTimeSeconds_max pvalues 0.036 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.019 TurnoutTimeSeconds_max pvalues 0.449 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.056 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.034 TurnoutTimeSeconds_max pvalues 0.031 True
# TurnoutTimeSeconds_mean pvalues 0.027 TurnoutTimeSeconds_max pvalues 0.025 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.155 TurnoutTimeSeconds_max pvalues 0.894 False
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.008 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.032 TurnoutTimeSeconds_max pvalues 0.014 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.03 TurnoutTimeSeconds_max pvalues 0.013 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.361 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.03 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.138 TurnoutTimeSeconds_max pvalues 0.031 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.175 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.0 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.091 TurnoutTimeSeconds_max pvalues 0.009 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.018 TurnoutTimeSeconds_max pvalues 0.012 True
# TurnoutTimeSeconds_mean pvalues 0.045 TurnoutTimeSeconds_max pvalues 0.02 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.043 TurnoutTimeSeconds_max pvalues 0.206 True
# TurnoutTimeSeconds_mean pvalues 0.016 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.021 TurnoutTimeSeconds_max pvalues 0.02 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.304 TurnoutTimeSeconds_max pvalues 0.399 False
# TurnoutTimeSeconds_mean pvalues 0.125 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.611 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.8 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.312 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.577 TurnoutTimeSeconds_max pvalues 0.465 False
# TurnoutTimeSeconds_mean pvalues 0.616 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.105 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.188 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.0 TurnoutTimeSeconds_max pvalues 0.269 True
#                                                     TurnoutTimeSeconds_min coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                -10.200
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                              -18.868
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                              -18.036
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                -14.160
# PropertyType[T.ART GALLERY]                                                     -16.716
#
#                                                     TurnoutTimeSeconds_min pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                             0.336
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                           0.061
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                           0.243
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                             0.187
# PropertyType[T.ART GALLERY]                                                  0.094
#
#                                                     TurnoutTimeSeconds_mean coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                 -27.175
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                               -31.739
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                               -30.304
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                 -31.838
# PropertyType[T.ART GALLERY]                                                      -31.842
#
#                                                     TurnoutTimeSeconds_mean pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                              0.011
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                            0.002
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                            0.053
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                              0.003
# PropertyType[T.ART GALLERY]                                                   0.002
#
#                                                     TurnoutTimeSeconds_max coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                -42.974
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                              -40.978
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                              -41.992
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                -49.378
# PropertyType[T.ART GALLERY]                                                     -46.381
#
#                                                     TurnoutTimeSeconds_max pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                             0.001
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                           0.001
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                           0.025
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                             0.000
# PropertyType[T.ART GALLERY]                                                  0.000
#
#                                                     Discord  Keep
# PropertyType[T.AIRPORT - HANGAR]                       True  True
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...     True  True
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...     True  True
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]       True  True
# PropertyType[T.ART GALLERY]                            True  True
# TravelTimeSeconds_mean pvalues 0.027 TravelTimeSeconds_max pvalues 0.038 True
# TravelTimeSeconds_mean pvalues 0.022 TravelTimeSeconds_max pvalues 0.025 True
# TravelTimeSeconds_mean pvalues 0.017 TravelTimeSeconds_max pvalues 0.027 True
# TravelTimeSeconds_mean pvalues 0.034 TravelTimeSeconds_max pvalues 0.074 True
# TravelTimeSeconds_mean pvalues 0.124 TravelTimeSeconds_max pvalues 0.321 False
# TravelTimeSeconds_mean pvalues 0.032 TravelTimeSeconds_max pvalues 0.036 True
# TravelTimeSeconds_mean pvalues 0.551 TravelTimeSeconds_max pvalues 0.033 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.057 True
# TravelTimeSeconds_mean pvalues 0.042 TravelTimeSeconds_max pvalues 0.05 True
# TravelTimeSeconds_mean pvalues 0.03 TravelTimeSeconds_max pvalues 0.041 True
# TravelTimeSeconds_mean pvalues 0.023 TravelTimeSeconds_max pvalues 0.035 True
# TravelTimeSeconds_mean pvalues 0.039 TravelTimeSeconds_max pvalues 0.057 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.024 True
# TravelTimeSeconds_mean pvalues 0.034 TravelTimeSeconds_max pvalues 0.161 True
# TravelTimeSeconds_mean pvalues 0.024 TravelTimeSeconds_max pvalues 0.027 True
# TravelTimeSeconds_mean pvalues 0.05 TravelTimeSeconds_max pvalues 0.064 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.049 True
# TravelTimeSeconds_mean pvalues 0.035 TravelTimeSeconds_max pvalues 0.047 True
# TravelTimeSeconds_mean pvalues 0.044 TravelTimeSeconds_max pvalues 0.056 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.025 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.037 True
# TravelTimeSeconds_mean pvalues 0.038 TravelTimeSeconds_max pvalues 0.042 True
# TravelTimeSeconds_mean pvalues 0.031 TravelTimeSeconds_max pvalues 0.051 True
# TravelTimeSeconds_mean pvalues 0.034 TravelTimeSeconds_max pvalues 0.047 True
# TravelTimeSeconds_mean pvalues 0.031 TravelTimeSeconds_max pvalues 0.044 True
# TravelTimeSeconds_mean pvalues 0.049 TravelTimeSeconds_max pvalues 0.042 True
# TravelTimeSeconds_mean pvalues 0.026 TravelTimeSeconds_max pvalues 0.042 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.038 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.043 True
# TravelTimeSeconds_mean pvalues 0.025 TravelTimeSeconds_max pvalues 0.028 True
# TravelTimeSeconds_mean pvalues 0.016 TravelTimeSeconds_max pvalues 0.019 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.025 True
# TravelTimeSeconds_mean pvalues 0.018 TravelTimeSeconds_max pvalues 0.023 True
# TravelTimeSeconds_mean pvalues 0.025 TravelTimeSeconds_max pvalues 0.027 True
# TravelTimeSeconds_mean pvalues 0.049 TravelTimeSeconds_max pvalues 0.057 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.034 True
# TravelTimeSeconds_mean pvalues 0.024 TravelTimeSeconds_max pvalues 0.029 True
# TravelTimeSeconds_mean pvalues 0.022 TravelTimeSeconds_max pvalues 0.02 True
# TravelTimeSeconds_mean pvalues 0.012 TravelTimeSeconds_max pvalues 0.009 True
# TravelTimeSeconds_mean pvalues 0.013 TravelTimeSeconds_max pvalues 0.012 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.017 True
# TravelTimeSeconds_mean pvalues 0.019 TravelTimeSeconds_max pvalues 0.026 True
# TravelTimeSeconds_mean pvalues 0.023 TravelTimeSeconds_max pvalues 0.022 True
# TravelTimeSeconds_mean pvalues 0.011 TravelTimeSeconds_max pvalues 0.074 True
# TravelTimeSeconds_mean pvalues 0.025 TravelTimeSeconds_max pvalues 0.019 True
# TravelTimeSeconds_mean pvalues 0.058 TravelTimeSeconds_max pvalues 0.222 False
# TravelTimeSeconds_mean pvalues 0.03 TravelTimeSeconds_max pvalues 0.03 True
# TravelTimeSeconds_mean pvalues 0.08 TravelTimeSeconds_max pvalues 0.209 False
# TravelTimeSeconds_mean pvalues 0.06 TravelTimeSeconds_max pvalues 0.042 True
# TravelTimeSeconds_mean pvalues 0.025 TravelTimeSeconds_max pvalues 0.063 True
# TravelTimeSeconds_mean pvalues 0.042 TravelTimeSeconds_max pvalues 0.105 True
# TravelTimeSeconds_mean pvalues 0.023 TravelTimeSeconds_max pvalues 0.087 True
# TravelTimeSeconds_mean pvalues 0.015 TravelTimeSeconds_max pvalues 0.078 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.016 True
# TravelTimeSeconds_mean pvalues 0.076 TravelTimeSeconds_max pvalues 0.03 True
# TravelTimeSeconds_mean pvalues 0.049 TravelTimeSeconds_max pvalues 0.023 True
# TravelTimeSeconds_mean pvalues 0.064 TravelTimeSeconds_max pvalues 0.04 True
# TravelTimeSeconds_mean pvalues 0.042 TravelTimeSeconds_max pvalues 0.019 True
# TravelTimeSeconds_mean pvalues 0.262 TravelTimeSeconds_max pvalues 0.966 False
# TravelTimeSeconds_mean pvalues 0.086 TravelTimeSeconds_max pvalues 0.508 False
# TravelTimeSeconds_mean pvalues 0.035 TravelTimeSeconds_max pvalues 0.013 True
# TravelTimeSeconds_mean pvalues 0.043 TravelTimeSeconds_max pvalues 0.056 True
# TravelTimeSeconds_mean pvalues 0.017 TravelTimeSeconds_max pvalues 0.053 True
# TravelTimeSeconds_mean pvalues 0.06 TravelTimeSeconds_max pvalues 0.15 False
# TravelTimeSeconds_mean pvalues 0.017 TravelTimeSeconds_max pvalues 0.099 True
# TravelTimeSeconds_mean pvalues 0.015 TravelTimeSeconds_max pvalues 0.061 True
# TravelTimeSeconds_mean pvalues 0.009 TravelTimeSeconds_max pvalues 0.093 True
# TravelTimeSeconds_mean pvalues 0.01 TravelTimeSeconds_max pvalues 0.004 True
# TravelTimeSeconds_mean pvalues 0.01 TravelTimeSeconds_max pvalues 0.004 True
# TravelTimeSeconds_mean pvalues 0.041 TravelTimeSeconds_max pvalues 0.041 True
# TravelTimeSeconds_mean pvalues 0.096 TravelTimeSeconds_max pvalues 0.001 True
# TravelTimeSeconds_mean pvalues 0.013 TravelTimeSeconds_max pvalues 0.079 True
# TravelTimeSeconds_mean pvalues 0.02 TravelTimeSeconds_max pvalues 0.085 True
# TravelTimeSeconds_mean pvalues 0.235 TravelTimeSeconds_max pvalues 0.006 True
# TravelTimeSeconds_mean pvalues 0.012 TravelTimeSeconds_max pvalues 0.006 True
# TravelTimeSeconds_mean pvalues 0.075 TravelTimeSeconds_max pvalues 0.046 True
# TravelTimeSeconds_mean pvalues 0.187 TravelTimeSeconds_max pvalues 0.447 False
# TravelTimeSeconds_mean pvalues 0.045 TravelTimeSeconds_max pvalues 0.102 True
# TravelTimeSeconds_mean pvalues 0.047 TravelTimeSeconds_max pvalues 0.095 True
# TravelTimeSeconds_mean pvalues 0.036 TravelTimeSeconds_max pvalues 0.01 True
# TravelTimeSeconds_mean pvalues 0.036 TravelTimeSeconds_max pvalues 0.036 True
# TravelTimeSeconds_mean pvalues 0.02 TravelTimeSeconds_max pvalues 0.207 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.102 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.084 True
# TravelTimeSeconds_mean pvalues 0.037 TravelTimeSeconds_max pvalues 0.074 True
# TravelTimeSeconds_mean pvalues 0.054 TravelTimeSeconds_max pvalues 0.209 False
# TravelTimeSeconds_mean pvalues 0.016 TravelTimeSeconds_max pvalues 0.011 True
# TravelTimeSeconds_mean pvalues 0.953 TravelTimeSeconds_max pvalues 0.021 True
# TravelTimeSeconds_mean pvalues 0.045 TravelTimeSeconds_max pvalues 0.055 True
# TravelTimeSeconds_mean pvalues 0.03 TravelTimeSeconds_max pvalues 0.016 True
# TravelTimeSeconds_mean pvalues 0.039 TravelTimeSeconds_max pvalues 0.203 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.011 True
# TravelTimeSeconds_mean pvalues 0.058 TravelTimeSeconds_max pvalues 0.045 True
# TravelTimeSeconds_mean pvalues 0.887 TravelTimeSeconds_max pvalues 0.052 False
# TravelTimeSeconds_mean pvalues 0.072 TravelTimeSeconds_max pvalues 0.734 False
# TravelTimeSeconds_mean pvalues 0.058 TravelTimeSeconds_max pvalues 0.449 False
# TravelTimeSeconds_mean pvalues 0.004 TravelTimeSeconds_max pvalues 0.001 True
# TravelTimeSeconds_mean pvalues 0.052 TravelTimeSeconds_max pvalues 0.023 True
# TravelTimeSeconds_mean pvalues 0.359 TravelTimeSeconds_max pvalues 0.386 False
# TravelTimeSeconds_mean pvalues 0.093 TravelTimeSeconds_max pvalues 0.228 False
# TravelTimeSeconds_mean pvalues 0.033 TravelTimeSeconds_max pvalues 0.063 True
# TravelTimeSeconds_mean pvalues 0.04 TravelTimeSeconds_max pvalues 0.091 True
# TravelTimeSeconds_mean pvalues 0.232 TravelTimeSeconds_max pvalues 0.688 False
# TravelTimeSeconds_mean pvalues 0.073 TravelTimeSeconds_max pvalues 0.387 False
# TravelTimeSeconds_mean pvalues 0.04 TravelTimeSeconds_max pvalues 0.147 True
# TravelTimeSeconds_mean pvalues 0.036 TravelTimeSeconds_max pvalues 0.114 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.006 True
# TravelTimeSeconds_mean pvalues 0.019 TravelTimeSeconds_max pvalues 0.126 True
# TravelTimeSeconds_mean pvalues 0.34 TravelTimeSeconds_max pvalues 0.529 False
# TravelTimeSeconds_mean pvalues 0.042 TravelTimeSeconds_max pvalues 0.059 True
# TravelTimeSeconds_mean pvalues 0.047 TravelTimeSeconds_max pvalues 0.104 True
# TravelTimeSeconds_mean pvalues 0.014 TravelTimeSeconds_max pvalues 0.098 True
# TravelTimeSeconds_mean pvalues 0.046 TravelTimeSeconds_max pvalues 0.042 True
# TravelTimeSeconds_mean pvalues 0.022 TravelTimeSeconds_max pvalues 0.013 True
# TravelTimeSeconds_mean pvalues 0.039 TravelTimeSeconds_max pvalues 0.025 True
# TravelTimeSeconds_mean pvalues 0.111 TravelTimeSeconds_max pvalues 0.377 False
# TravelTimeSeconds_mean pvalues 0.026 TravelTimeSeconds_max pvalues 0.245 True
# TravelTimeSeconds_mean pvalues 0.019 TravelTimeSeconds_max pvalues 0.018 True
# TravelTimeSeconds_mean pvalues 0.051 TravelTimeSeconds_max pvalues 0.15 False
# TravelTimeSeconds_mean pvalues 0.031 TravelTimeSeconds_max pvalues 0.462 True
# TravelTimeSeconds_mean pvalues 0.007 TravelTimeSeconds_max pvalues 0.053 True
# TravelTimeSeconds_mean pvalues 0.018 TravelTimeSeconds_max pvalues 0.013 True
# TravelTimeSeconds_mean pvalues 0.022 TravelTimeSeconds_max pvalues 0.082 True
# TravelTimeSeconds_mean pvalues 0.061 TravelTimeSeconds_max pvalues 0.616 False
# TravelTimeSeconds_mean pvalues 0.035 TravelTimeSeconds_max pvalues 0.166 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.11 True
# TravelTimeSeconds_mean pvalues 0.069 TravelTimeSeconds_max pvalues 0.033 True
# TravelTimeSeconds_mean pvalues 0.041 TravelTimeSeconds_max pvalues 0.06 True
# TravelTimeSeconds_mean pvalues 0.034 TravelTimeSeconds_max pvalues 0.017 True
# TravelTimeSeconds_mean pvalues 0.057 TravelTimeSeconds_max pvalues 0.032 True
# TravelTimeSeconds_mean pvalues 0.042 TravelTimeSeconds_max pvalues 0.043 True
# TravelTimeSeconds_mean pvalues 0.021 TravelTimeSeconds_max pvalues 0.117 True
# TravelTimeSeconds_mean pvalues 0.735 TravelTimeSeconds_max pvalues 0.032 True
# TravelTimeSeconds_mean pvalues 0.061 TravelTimeSeconds_max pvalues 0.001 True
# TravelTimeSeconds_mean pvalues 0.251 TravelTimeSeconds_max pvalues 0.0 True
# TravelTimeSeconds_mean pvalues 0.523 TravelTimeSeconds_max pvalues 0.0 True
#                            TravelTimeSeconds_min coefficients  \
# Postcode_district[T.BR2]                              -85.978
# Postcode_district[T.BR5]                              -86.692
# Postcode_district[T.BR6]                              -96.375
# Postcode_district[T.CM13]                             151.945
# Postcode_district[T.CM14]                             116.283
#
#                            TravelTimeSeconds_min pvalues  \
# Postcode_district[T.BR2]                           0.082
# Postcode_district[T.BR5]                           0.080
# Postcode_district[T.BR6]                           0.051
# Postcode_district[T.CM13]                          0.015
# Postcode_district[T.CM14]                          0.025
#
#                            TravelTimeSeconds_mean coefficients  \
# Postcode_district[T.BR2]                              -113.192
# Postcode_district[T.BR5]                              -117.334
# Postcode_district[T.BR6]                              -121.691
# Postcode_district[T.CM13]                              136.776
# Postcode_district[T.CM14]                               82.643
#
#                            TravelTimeSeconds_mean pvalues  \
# Postcode_district[T.BR2]                            0.027
# Postcode_district[T.BR5]                            0.022
# Postcode_district[T.BR6]                            0.017
# Postcode_district[T.CM13]                           0.034
# Postcode_district[T.CM14]                           0.124
#
#                            TravelTimeSeconds_max coefficients  \
# Postcode_district[T.BR2]                             -123.569
# Postcode_district[T.BR5]                             -133.070
# Postcode_district[T.BR6]                             -132.035
# Postcode_district[T.CM13]                             134.681
# Postcode_district[T.CM14]                              62.139
#
#                            TravelTimeSeconds_max pvalues  Discord   Keep
# Postcode_district[T.BR2]                           0.038     True   True
# Postcode_district[T.BR5]                           0.025     True   True
# Postcode_district[T.BR6]                           0.027     True   True
# Postcode_district[T.CM13]                          0.074     True   True
# Postcode_district[T.CM14]                          0.321     True  False
# PumpSecondsOnSite 106 discords, 87 keeps, sur 616, conserve 14.0%
# TurnoutTimeSeconds 133 discords, 287 keeps, sur 616, conserve 47.0%
# TravelTimeSeconds 136 discords, 443 keeps, sur 616, conserve 72.0%
#                             Keep             Column Value
# Postcode_district[T.BR1]   False  Postcode_district   BR1
# Postcode_district[T.BR2]   False  Postcode_district   BR2
# Postcode_district[T.BR3]   False  Postcode_district   BR3
# Postcode_district[T.BR4]   False  Postcode_district   BR4
# Postcode_district[T.BR5]   False  Postcode_district   BR5
# Postcode_district[T.BR6]   False  Postcode_district   BR6
# Postcode_district[T.BR7]   False  Postcode_district   BR7
# Postcode_district[T.BR8]    True  Postcode_district   BR8
# Postcode_district[T.CM13]  False  Postcode_district  CM13
# Postcode_district[T.CM14]  False  Postcode_district  CM14
# keep PumpSecondsOnSite
#                             Keep             Column Value
# Postcode_district[T.BR1]   False  Postcode_district   BR1
# Postcode_district[T.BR2]   False  Postcode_district   BR2
# Postcode_district[T.BR3]   False  Postcode_district   BR3
# Postcode_district[T.BR4]   False  Postcode_district   BR4
# Postcode_district[T.BR5]   False  Postcode_district   BR5
# Postcode_district[T.BR6]   False  Postcode_district   BR6
# Postcode_district[T.BR7]   False  Postcode_district   BR7
# Postcode_district[T.BR8]   False  Postcode_district   BR8
# Postcode_district[T.CM13]  False  Postcode_district  CM13
# Postcode_district[T.CM14]  False  Postcode_district  CM14
# keep TurnoutTimeSeconds
#                             Keep             Column Value
# Postcode_district[T.BR1]    True  Postcode_district   BR1
# Postcode_district[T.BR2]    True  Postcode_district   BR2
# Postcode_district[T.BR3]    True  Postcode_district   BR3
# Postcode_district[T.BR4]   False  Postcode_district   BR4
# Postcode_district[T.BR5]    True  Postcode_district   BR5
# Postcode_district[T.BR6]    True  Postcode_district   BR6
# Postcode_district[T.BR7]   False  Postcode_district   BR7
# Postcode_district[T.BR8]   False  Postcode_district   BR8
# Postcode_district[T.CM13]   True  Postcode_district  CM13
# Postcode_district[T.CM14]  False  Postcode_district  CM14
# keep TravelTimeSeconds
