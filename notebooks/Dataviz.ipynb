# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import seaborn as sns

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/Merge.csv", sep=";", index_col=0, low_memory=False)
df = df.drop(["Postcode_full", "UPRN", "IncGeo_BoroughCode", "ProperCase", "IncGeo_WardCode" ,"IncGeo_WardName", 
    "Easting_m",
    "Northing_m",
    "Latitude",
    "Longitude",
    "FRS",
    "FirstPumpArriving_AttendanceTime",
    #"FirstPumpArriving_DeployedFromStation",
    "SecondPumpArriving_AttendanceTime",
    "SecondPumpArriving_DeployedFromStation",
    "PumpMinutesRounded",
    "Notional Cost (£)",
    "NumCalls", "PumpOrder"],
    axis=1)

df.DateOfCall = pd.to_datetime(df.DateOfCall)
df.TimeOfCall = pd.to_datetime(df.TimeOfCall)
df.DateAndTimeMobilised = pd.to_datetime(df.DateAndTimeMobilised)
df.DateAndTimeMobile = pd.to_datetime(df.DateAndTimeMobile)
df.DateAndTimeArrived = pd.to_datetime(df.DateAndTimeArrived)
df.DateAndTimeLeft = pd.to_datetime(df.DateAndTimeLeft)
df.DateAndTimeReturned = pd.to_datetime(df.DateAndTimeReturned)

display(df.head())
display(df.info())
display(df.describe())
# Out:
#   IncidentNumber DateOfCall  CalYear          TimeOfCall  HourOfCall  \
# 0      235138081 2009-01-01     2009 1900-01-01 00:00:37           0
# 1           1091 2009-01-01     2009 1900-01-01 00:00:46           0
# 2           2091 2009-01-01     2009 1900-01-01 00:03:00           0
# 3           3091 2009-01-01     2009 1900-01-01 00:04:27           0
# 4           5091 2009-01-01     2009 1900-01-01 00:05:39           0
#
#      IncidentGroup StopCodeDescription     SpecialServiceType  \
# 0  Special Service     Special Service                    RTC
# 1  Special Service     Special Service  Assist other agencies
# 2             Fire      Secondary Fire                    NaN
# 3             Fire      Secondary Fire                    NaN
# 4             Fire      Secondary Fire                    NaN
#
#   PropertyCategory                                 PropertyType  \
# 0     Road Vehicle                                         Car
# ...

# %%
val_num = df.select_dtypes(include=["int", "float"])
plt.figure(figsize=(20, 8))
sns.heatmap(val_num.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
g = sns.catplot(
    x="IncGeo_BoroughName",
    y="TurnoutTimeSeconds_min",
    data=df[df.CalYear > 2022],
    kind="box",
    col="CalYear",
)
g.set_xticklabels(rotation=90)
g.figure.suptitle("TurnoutTimeSeconds_min par commune", y=1.02)

plt.show()

# %%
g = sns.catplot(
    x="IncGeo_BoroughName",
    y="TravelTimeSeconds_min",
    data=df[df.CalYear > 2022],
    kind="box",
    col="CalYear",
)
g.set_xticklabels(rotation=90)
g.figure.suptitle("TravelTimeSeconds_min par commune", y=1.02)

plt.show()

# %%
g = sns.catplot(
    x="StopCodeDescription",
    y="TurnoutTimeSeconds_min",
    data=df[df.CalYear > 2022],
    kind="box",
    col="CalYear",
)
g.set_xticklabels(rotation=90)
g.figure.suptitle("TurnoutTimeSeconds_min par catégorie d'incident", y=1.02)

plt.show()

# %%
g = sns.catplot(
    x="StopCodeDescription",
    y="TravelTimeSeconds_min",
    data=df[df.CalYear > 2022],
    kind="box",
    col="CalYear",
)
g.set_xticklabels(rotation=90)
g.figure.suptitle("TravelTimeSeconds_min par catégorie d'incident", y=1.02)

plt.show()

# %%
g = sns.catplot(
    x="StopCodeDescription",
    y="PumpSecondsOnSite_min",
    data=df[df.CalYear > 2022],
    kind="box",
    col="CalYear",
)
g.set_xticklabels(rotation=90)
g.figure.suptitle("PumpSecondsOnSite_min par catégorie d'incident", y=1.02)

plt.show()

# %%
def ShowAnalyse
# Temps par heure
# TravelTimeSeconds_min
# PumpSecondsOnSite_min

plt.figure(figsize=(20, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("HourOfCall")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("HourOfCall")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby('HourOfCall')['PumpSecondsOnSite_min'].mean()

df4 = df_temp.groupby("HourOfCall")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("HourOfCall")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("HourOfCall")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("HourOfCall")["TravelTimeSeconds_max"].max()

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min", color='#00aeff')
sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds", color='#0066ff')
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max", color='#0000ff')
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min", color='#ffae00')
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds", color='#ff6600')
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max", color='#ff0000')
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite", color='#00ff00')

plt.title("Temps par créneau horaire")
plt.legend()
plt.show()

# %%
# Temps par heure
# TravelTimeSeconds_min
# PumpSecondsOnSite_min

plt.figure(figsize=(20, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("IncidentStationGround")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("IncidentStationGround")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby("IncidentStationGround")["PumpSecondsOnSite_min"].mean()

df4 = df_temp.groupby("IncidentStationGround")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("IncidentStationGround")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("IncidentStationGround")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("IncidentStationGround")["TravelTimeSeconds_max"].max()


sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds")
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds")
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite")

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min")
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max")
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min")
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max")
plt.title("Temps par terrain de station")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("StopCodeDescription")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("StopCodeDescription")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby("StopCodeDescription")["PumpSecondsOnSite_min"].mean()

df4 = df_temp.groupby("StopCodeDescription")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("StopCodeDescription")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("StopCodeDescription")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("StopCodeDescription")["TravelTimeSeconds_max"].max()


sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds")
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds")
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite")

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min")
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max")
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min")
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max")
plt.title("Temps par catégorie d'incident détaillée")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("SpecialServiceType")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("SpecialServiceType")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby("SpecialServiceType")["PumpSecondsOnSite_min"].mean()

df4 = df_temp.groupby("SpecialServiceType")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("SpecialServiceType")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("SpecialServiceType")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("SpecialServiceType")["TravelTimeSeconds_max"].max()

sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds")
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds")
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite")

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min")
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max")
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min")
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max")
plt.title("Temps par catégories d'incidents de services spéciaux")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("PropertyCategory")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("PropertyCategory")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby("PropertyCategory")["PumpSecondsOnSite_min"].mean()

df4 = df_temp.groupby("PropertyCategory")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("PropertyCategory")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("PropertyCategory")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("PropertyCategory")["TravelTimeSeconds_max"].max()


sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds")
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds")
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite")

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min")
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max")
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min")
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max")
plt.title("Temps median par territoire")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(60, 8))

df_temp = df[df.CalYear > 2022]

df1 = df_temp.groupby("PropertyType")["TurnoutTimeSeconds_min"].mean()
df2 = df_temp.groupby("PropertyType")["TravelTimeSeconds_min"].mean()
df3 = df_temp.groupby("PropertyType")["PumpSecondsOnSite_min"].mean()

df4 = df_temp.groupby("PropertyType")["TurnoutTimeSeconds_min"].min()
df5 = df_temp.groupby("PropertyType")["TurnoutTimeSeconds_max"].max()
df6 = df_temp.groupby("PropertyType")["TravelTimeSeconds_min"].min()
df7 = df_temp.groupby("PropertyType")["TravelTimeSeconds_max"].max()


sns.lineplot(x=df1.index, y=df1.values, marker="o", label="TurnoutTimeSeconds")
sns.lineplot(x=df2.index, y=df2.values, marker="o", label="TravelTimeSeconds")
sns.lineplot(x=df3.index, y=df3.values, marker="o", label="PumpSecondsOnSite")

sns.lineplot(x=df4.index, y=df4.values, marker="o", label="TurnoutTimeSeconds_min")
sns.lineplot(x=df5.index, y=df5.values, marker="o", label="TurnoutTimeSeconds_max")
sns.lineplot(x=df6.index, y=df6.values, marker="o", label="TravelTimeSeconds_min")
sns.lineplot(x=df7.index, y=df7.values, marker="o", label="TravelTimeSeconds_max")
plt.title("Temps median par type de propriété")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
quartile

ecart type
tab croisé 
répartition des classes et temps
Evolution annuel des temps 

temps sur site à calculer et par an 

grouper par IncidentGroup et StopCodeDescription
# Out:
#   Cell In[84], line 3
#     ecart type
#           ^
# SyntaxError: invalid syntax
