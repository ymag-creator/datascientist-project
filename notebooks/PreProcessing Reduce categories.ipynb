# %%
# ------------------------- Préparation des informations de réduction des valeurs catégorielles -----------------------------

import pandas as pd
import statsmodels.api
from statsmodels.api import stats
import statsmodels.formula.api as smf

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
def load_incidents():
    df = pd.read_csv("../data/PreProcess.csv", sep=";", low_memory=False)
    display(df.head())
    display(df.info())
    return df

# %%
# Traitmeent des catégories StopCode, PropertyType, Postcode_district
# Pour conserver les valeurs catégorielles en fonction d'un 
# Test de Anova, pour chacune des cibles

cols_cible_type = ["PumpSecondsOnSite", "TurnoutTimeSeconds", "TravelTimeSeconds"]

def calc_anova_for_all_targets(df):
    # Catégories
    cols_categ = [
        "StopCode",
        "PropertyType",
        "Postcode_district",
    ]
    # Cibles à caluler
    cols_cible = [
        ["PumpSecondsOnSite_min", "PumpSecondsOnSite_mean", "PumpSecondsOnSite_max"],
        ["TurnoutTimeSeconds_min", "TurnoutTimeSeconds_mean", "TurnoutTimeSeconds_max"],
        ["TravelTimeSeconds_min", "TravelTimeSeconds_mean", "TravelTimeSeconds_max"],
    ]

    # Nb de valeurs actuelles par catégories
    for col in cols_categ:
        print(col, len(df[col].unique()))
    print()

    # Test de Anova sur les données après 2016, pour réduire le temps de calcul
    df_temp = df[df.CalYear.astype("int") > 2016]

    # Test de Anova sur chaque colonne cible avec toutes les colonnes catégorielles
    all_result = []
    # Formatage des colonnes catégorielles pour le test de Anova
    cols_to_check = "+".join(cols_categ)
    # Pour chaque tableau, par type de cible 
    # (exemple PumpSecondsOnSite, calcul pour min, mean, max)
    for cols in cols_cible:
        cible_results = []
        # Pour chaque valeur à calculer (min, max, mean)
        for col in cols:
            print("Test de", col)
            # Test de Anova pour une cible, par exemple PumpSecondsOnSite_min
            results = smf.ols(f"{col} ~ {cols_to_check}", data=df_temp).fit()
            # table = stats.anova_lm(result)
            # display(table)
            # Création d'un Dataframe du résultat avec le coefficient et la pvalue
            results_df = pd.DataFrame(
                {
                    f"{col} coefficients": round(results.params, 3),
                    f"{col} pvalues": round(results.pvalues, 3),
                }
            )
            # Ajoute le résultat au tableau par type de cible
            cible_results.append(results_df)
            # display(results_df.head(30))
            # print("Test de", col, "ok")
        # Ajoute le résultat par type de cible aux résultats globaux
        all_result.append(cible_results)

    # Contrôle
    for cible_results in all_result:
        for result in cible_results:
            display(result.head(5))

    # Merge les resultats dans un dataFrame, en gardant un Dataframe par type de cible
    # et en mettant les résultats pvalue et codef par min, mean et max en colonne
    compiled_results = []
    for cible_results in all_result:
        cible_result = cible_results[0]
        i = 0
        for result in cible_results:
            if i == 0:
                print("continue")
                i += 1
                continue
            print("merge")
            cible_result = pd.merge(
                cible_result, result, left_index=True, right_index=True, how="outer"
            )
        compiled_results.append(cible_result)

    return compiled_results



# Ajoute 2 colonnes Discord et Keep dans les DF pour finaliser le choix 
# des valeurs catégorielles à conserver 
def calculate_keeps_by_target(compiled_results):
    print("Calcule Discords")

    # Regarde si la pvalue est la même par valeur catégorielle pour min, max et mean 
    # Ajout de la colonne Discord : True si il y a des delta
    # Filtre les lignes avec que des pvalue > 0.05 ou que que des pvalue < 0.05
    # pour voir si certaines interviennent que dans certains cas
    # Utiliser uniquement pour contrôle 
    def TreatDiscordRow(columns, row):
        keeps = []
        nb = 0
        for i in range(1, len(columns), 2):
            # print("col", columns[i])
            # print(row)
            # Crée un tablea à 3 bool qui indique si <= 0.05 ou non 
            keeps.append(row[columns[i]] <= 0.05)
            nb += 1
        # Somme des 3 bool, si le résultat donne 3 ou 0 alors les 3 pvalue
        # sont uniformes, sinon non, donc Discord
        val = not (sum(keeps) == 0) | (sum(keeps) == nb)  # sum(keeps)
        # print(val)
        return val

    # Calcul final pour savoir si la valeur caétorielle est conservée pour 
    # le type de cible. Oui si toutes les pvalues sont >= 0.05 ou si 
    # meam et max le sont
    def TreatKeepRow(columns, row):
        keeps = []
        nb = 0
        for i in range(1, len(columns), 2):
            # print("col", columns[i])
            # print(row[columns[i]])
            keeps.append(row[columns[i]] <= 0.05)
            nb += 1
        val = sum(keeps)
        # si toutes les pvalues sont non significatives
        if val == 0:
            return False
        # si toutes les pvalues sont significatives
        elif val == nb:
            return True
        # sinon, conserve si c'est significatif sur la moyenne ou max
        else:
            mean_col = [s for s in columns if "mean pvalues" in s][0]
            max_col = [s for s in columns if "max pvalues" in s][0]            
            mean = row[mean_col]
            max = row[max_col]
            keep = True if (mean <= 0.05) | (max <= 0.05) else False
            print(mean_col, mean, max_col, max, keep)
            # print("mean_col", mean_col)
            # print("mean_col", val)
            return keep

    # Pour chaque type de cible (ex : PumpSecondsOnSite) on a un DF avec les 
    # pvalue par cible min, max, mean et une ligne par valezur de catégorie
    for cible_results in compiled_results:
        # display(cible_results.head())
        # Ajout d'une colonne Discord qui indique si les pvalue sont toutes
        # <0.05 ou > 0.05, donc un Keep évident
        cible_results["Discord"] = cible_results.apply(
            lambda row: TreatDiscordRow(cible_results.columns, row), axis=1
        )
        # Calcul si on garde ou non la veleur catégorielle pour un type de cible
        cible_results["Keep"] = cible_results.apply(
            lambda row: TreatKeepRow(cible_results.columns, row), axis=1
        )
        # Contrôle
        display(cible_results[cible_results.Discord == True].head())
    # Résumé des données conserver par type de cible
    for i in range(0, len(compiled_results)):
        print(
            f"{cols_cible_type[i]} {compiled_results[i]["Discord"].sum()} discords, {compiled_results[i]["Keep"].sum()} keeps, sur {len(compiled_results[i])}, "
            f"conserve {round(compiled_results[i]["Keep"].sum() / len(compiled_results[i]) * 100, 0)}%"
        )
    return compiled_results

# %%
def save_categorical_reduction(compiled_results):
    def SplitCatValue(s, return_name):
        result = s.split("[")
        return result[0] if return_name else result[1][2:-1]

    # Sauve les infos des valeurs catégorielles 
    for i in range(0, len(compiled_results)):
        # Conserve uniquement la valeur Keep, qui est le résultat final
        # L'index étant la valeur catégorielle
        df_to_save = compiled_results[i][["Keep"]]
        # supprime la ligne Intercept
        df_to_save = df_to_save.drop(
            df_to_save[df_to_save.index.str.upper() == "INTERCEPT"].index
        )
        # Les valeurs de df_keep ont le format
        #           AddressQualifier[T.IN STREET CLOSE TO GAZETTEER LOCATION]	True (colonne Keep)
        # Crée 2 colonnes, nom de colonne et valeur
        # Prend l'index
        df_to_save["Column"] = df_to_save.index
        # Split l'index et retourne la 1ere partie qui est le nom de la catégorie
        df_to_save["Column"] = df_to_save["Column"].apply(lambda s: SplitCatValue(s, True))
        df_to_save["Value"] = df_to_save.index
        # Split l'index et retourne la 2eme partie qui est la valeur catégorielle
        df_to_save["Value"] = df_to_save["Value"].apply(lambda s: SplitCatValue(s, False))
        display(df_to_save.head())
        # Sauvegarde le DF dans un fichier
        name = f"keep {cols_cible_type[i]}"
        print(name)
        df_to_save.to_csv(f"../data/{name}.csv", sep=";", index=False)

# %%
df = load_incidents()
compiled_results = calc_anova_for_all_targets(df)
compiled_results = calculate_keeps_by_target(compiled_results)
save_categorical_reduction(compiled_results)
# 10 minutes
# Out:
#   IncidentNumber  CalYear  HourOfCall  \
# 0      235138081     2009           0
# 1           2091     2009           0
# 2           3091     2009           0
# 3           5091     2009           0
# 4           6091     2009           0
#
#                                         PropertyType Postcode_district  \
# 0                                                CAR              SW11
# 1                              ROAD SURFACE/PAVEMENT                N9
# 2         DOMESTIC GARDEN (VEGETATION NOT EQUIPMENT)              UB10
# 3               CYCLE PATH/PUBLIC FOOTPATH/BRIDLEWAY                N7
# 4  PURPOSE BUILT FLATS/MAISONETTES - UP TO 3 STOREYS               NW5
#
#   FirstPumpArriving_DeployedFromStation  NumPumpsAttending        StopCode  \
# 0                             BATTERSEA                2.0         SST-RTC
# 1                              EDMONTON                1.0  SECONDARY FIRE
# 2                            HILLINGDON                1.0  SECONDARY FIRE
# 3                              HOLLOWAY                2.0  SECONDARY FIRE
# 4                          KENTISH TOWN                2.0             AFA
#
#    Month  DayOfWeek  PumpSecondsOnSite_min  PumpSecondsOnSite_mean  \
# 0      1          4                  240.0                   390.0
# 1      1          4                  420.0                   420.0
# 2      1          4                  720.0                   720.0
# 3      1          4                  120.0                   120.0
# 4      1          4                  360.0                   360.0
#
#    PumpSecondsOnSite_max  TurnoutTimeSeconds_min  TurnoutTimeSeconds_mean  \
# 0                  540.0                   253.0                    253.0
# 1                  420.0                   151.0                    151.0
# 2                  720.0                   108.0                    108.0
# 3                  120.0                   114.0                    128.0
# 4                  360.0                    83.0                     89.0
#
#    TurnoutTimeSeconds_max  TravelTimeSeconds_min  TravelTimeSeconds_mean  \
# 0                   253.0                   89.0                    89.0
# 1                   151.0                  157.0                   157.0
# 2                   108.0                  102.0                   102.0
# 3                   142.0                  108.0                   113.5
# 4                    95.0                   89.0                   108.0
#
#    TravelTimeSeconds_max
# 0                   89.0
# 1                  157.0
# 2                  102.0
# 3                  119.0
# 4                  127.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591519 entries, 0 to 1591518
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   IncidentNumber                         1591519 non-null  object
#  1   CalYear                                1591519 non-null  int64
#  2   HourOfCall                             1591519 non-null  int64
#  3   PropertyType                           1591519 non-null  object
#  4   Postcode_district                      1591519 non-null  object
#  5   FirstPumpArriving_DeployedFromStation  1591519 non-null  object
#  6   NumPumpsAttending                      1591519 non-null  float64
#  7   StopCode                               1591519 non-null  object
#  8   Month                                  1591519 non-null  int64
#  9   DayOfWeek                              1591519 non-null  int64
#  10  PumpSecondsOnSite_min                  1591519 non-null  float64
#  11  PumpSecondsOnSite_mean                 1591519 non-null  float64
#  12  PumpSecondsOnSite_max                  1591519 non-null  float64
#  13  TurnoutTimeSeconds_min                 1591519 non-null  float64
#  14  TurnoutTimeSeconds_mean                1591519 non-null  float64
#  15  TurnoutTimeSeconds_max                 1591519 non-null  float64
#  16  TravelTimeSeconds_min                  1591519 non-null  float64
#  17  TravelTimeSeconds_mean                 1591519 non-null  float64
#  18  TravelTimeSeconds_max                  1591519 non-null  float64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 230.7+ MB
# None
# StopCode 28
# PropertyType 292
# Postcode_district 324
#
# Test de PumpSecondsOnSite_min
# Test de PumpSecondsOnSite_mean
# Test de PumpSecondsOnSite_max
# Test de TurnoutTimeSeconds_min
# Test de TurnoutTimeSeconds_mean
# Test de TurnoutTimeSeconds_max
# Test de TravelTimeSeconds_min
# Test de TravelTimeSeconds_mean
# Test de TravelTimeSeconds_max
#                                        PumpSecondsOnSite_min coefficients  \
# Intercept                                                         720.310
# StopCode[T.CHIMNEY FIRE]                                         2909.027
# StopCode[T.FALSE ALARM - GOOD INTENT]                             168.508
# StopCode[T.FALSE ALARM - MALICIOUS]                               107.859
# StopCode[T.LATE CALL]                                            1278.401
#
#                                        PumpSecondsOnSite_min pvalues
# Intercept                                                      0.245
# StopCode[T.CHIMNEY FIRE]                                       0.000
# StopCode[T.FALSE ALARM - GOOD INTENT]                          0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                            0.000
# StopCode[T.LATE CALL]                                          0.000
#                                        PumpSecondsOnSite_mean coefficients  \
# Intercept                                                          539.713
# StopCode[T.CHIMNEY FIRE]                                          3075.949
# StopCode[T.FALSE ALARM - GOOD INTENT]                              209.920
# StopCode[T.FALSE ALARM - MALICIOUS]                                122.294
# StopCode[T.LATE CALL]                                             1189.866
#
#                                        PumpSecondsOnSite_mean pvalues
# Intercept                                                       0.405
# StopCode[T.CHIMNEY FIRE]                                        0.000
# StopCode[T.FALSE ALARM - GOOD INTENT]                           0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                             0.000
# StopCode[T.LATE CALL]                                           0.000
#                                        PumpSecondsOnSite_max coefficients  \
# Intercept                                                         212.292
# StopCode[T.CHIMNEY FIRE]                                         3220.292
# StopCode[T.FALSE ALARM - GOOD INTENT]                             254.143
# StopCode[T.FALSE ALARM - MALICIOUS]                               136.048
# StopCode[T.LATE CALL]                                            1086.063
#
#                                        PumpSecondsOnSite_max pvalues
# Intercept                                                      0.771
# StopCode[T.CHIMNEY FIRE]                                       0.000
# StopCode[T.FALSE ALARM - GOOD INTENT]                          0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                            0.000
# StopCode[T.LATE CALL]                                          0.000
#                                        TurnoutTimeSeconds_min coefficients  \
# Intercept                                                           86.776
# StopCode[T.CHIMNEY FIRE]                                             2.490
# StopCode[T.FALSE ALARM - GOOD INTENT]                                1.652
# StopCode[T.FALSE ALARM - MALICIOUS]                                  3.136
# StopCode[T.LATE CALL]                                               16.542
#
#                                        TurnoutTimeSeconds_min pvalues
# Intercept                                                       0.000
# StopCode[T.CHIMNEY FIRE]                                        0.402
# StopCode[T.FALSE ALARM - GOOD INTENT]                           0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                             0.000
# StopCode[T.LATE CALL]                                           0.003
#                                        TurnoutTimeSeconds_mean coefficients  \
# Intercept                                                           103.410
# StopCode[T.CHIMNEY FIRE]                                              1.262
# StopCode[T.FALSE ALARM - GOOD INTENT]                                 1.369
# StopCode[T.FALSE ALARM - MALICIOUS]                                   2.909
# StopCode[T.LATE CALL]                                                 5.942
#
#                                        TurnoutTimeSeconds_mean pvalues
# Intercept                                                        0.000
# StopCode[T.CHIMNEY FIRE]                                         0.676
# StopCode[T.FALSE ALARM - GOOD INTENT]                            0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                              0.000
# StopCode[T.LATE CALL]                                            0.299
#                                        TurnoutTimeSeconds_max coefficients  \
# Intercept                                                          121.902
# StopCode[T.CHIMNEY FIRE]                                            -0.460
# StopCode[T.FALSE ALARM - GOOD INTENT]                                1.235
# StopCode[T.FALSE ALARM - MALICIOUS]                                  2.864
# StopCode[T.LATE CALL]                                               -5.344
#
#                                        TurnoutTimeSeconds_max pvalues
# Intercept                                                       0.000
# StopCode[T.CHIMNEY FIRE]                                        0.898
# StopCode[T.FALSE ALARM - GOOD INTENT]                           0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                             0.000
# StopCode[T.LATE CALL]                                           0.433
#                                        TravelTimeSeconds_min coefficients  \
# Intercept                                                         445.025
# StopCode[T.CHIMNEY FIRE]                                            2.059
# StopCode[T.FALSE ALARM - GOOD INTENT]                              12.353
# StopCode[T.FALSE ALARM - MALICIOUS]                                 4.146
# StopCode[T.LATE CALL]                                              38.344
#
#                                        TravelTimeSeconds_min pvalues
# Intercept                                                      0.000
# StopCode[T.CHIMNEY FIRE]                                       0.838
# StopCode[T.FALSE ALARM - GOOD INTENT]                          0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                            0.002
# StopCode[T.LATE CALL]                                          0.045
#                                        TravelTimeSeconds_mean coefficients  \
# Intercept                                                          499.387
# StopCode[T.CHIMNEY FIRE]                                            -2.072
# StopCode[T.FALSE ALARM - GOOD INTENT]                               14.355
# StopCode[T.FALSE ALARM - MALICIOUS]                                  5.931
# StopCode[T.LATE CALL]                                               -2.839
#
#                                        TravelTimeSeconds_mean pvalues
# Intercept                                                       0.000
# StopCode[T.CHIMNEY FIRE]                                        0.842
# StopCode[T.FALSE ALARM - GOOD INTENT]                           0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                             0.000
# StopCode[T.LATE CALL]                                           0.885
#                                        TravelTimeSeconds_max coefficients  \
# Intercept                                                         547.525
# StopCode[T.CHIMNEY FIRE]                                           -6.108
# StopCode[T.FALSE ALARM - GOOD INTENT]                              17.200
# StopCode[T.FALSE ALARM - MALICIOUS]                                 8.682
# StopCode[T.LATE CALL]                                             -44.424
#
#                                        TravelTimeSeconds_max pvalues
# Intercept                                                      0.000
# StopCode[T.CHIMNEY FIRE]                                       0.615
# StopCode[T.FALSE ALARM - GOOD INTENT]                          0.000
# StopCode[T.FALSE ALARM - MALICIOUS]                            0.000
# StopCode[T.LATE CALL]                                          0.054
# continue
# merge
# merge
# continue
# merge
# merge
# continue
# merge
# merge
# Calcule Discords
# PumpSecondsOnSite_mean pvalues 0.079 PumpSecondsOnSite_max pvalues 0.14 False
# PumpSecondsOnSite_mean pvalues 0.142 PumpSecondsOnSite_max pvalues 0.753 False
# PumpSecondsOnSite_mean pvalues 0.055 PumpSecondsOnSite_max pvalues 0.298 False
# PumpSecondsOnSite_mean pvalues 0.263 PumpSecondsOnSite_max pvalues 0.016 True
# PumpSecondsOnSite_mean pvalues 0.305 PumpSecondsOnSite_max pvalues 0.924 False
# PumpSecondsOnSite_mean pvalues 0.127 PumpSecondsOnSite_max pvalues 0.672 False
# PumpSecondsOnSite_mean pvalues 0.275 PumpSecondsOnSite_max pvalues 0.973 False
# PumpSecondsOnSite_mean pvalues 0.175 PumpSecondsOnSite_max pvalues 0.699 False
# PumpSecondsOnSite_mean pvalues 0.138 PumpSecondsOnSite_max pvalues 0.588 False
# PumpSecondsOnSite_mean pvalues 0.293 PumpSecondsOnSite_max pvalues 0.962 False
# PumpSecondsOnSite_mean pvalues 0.058 PumpSecondsOnSite_max pvalues 0.191 False
# PumpSecondsOnSite_mean pvalues 0.048 PumpSecondsOnSite_max pvalues 0.091 True
# PumpSecondsOnSite_mean pvalues 0.02 PumpSecondsOnSite_max pvalues 0.056 True
# PumpSecondsOnSite_mean pvalues 0.059 PumpSecondsOnSite_max pvalues 0.372 False
# PumpSecondsOnSite_mean pvalues 0.101 PumpSecondsOnSite_max pvalues 0.568 False
# PumpSecondsOnSite_mean pvalues 0.028 PumpSecondsOnSite_max pvalues 0.248 True
# PumpSecondsOnSite_mean pvalues 0.165 PumpSecondsOnSite_max pvalues 0.549 False
# PumpSecondsOnSite_mean pvalues 0.067 PumpSecondsOnSite_max pvalues 0.476 False
# PumpSecondsOnSite_mean pvalues 0.212 PumpSecondsOnSite_max pvalues 0.911 False
# PumpSecondsOnSite_mean pvalues 0.225 PumpSecondsOnSite_max pvalues 0.725 False
# PumpSecondsOnSite_mean pvalues 0.232 PumpSecondsOnSite_max pvalues 0.725 False
# PumpSecondsOnSite_mean pvalues 0.032 PumpSecondsOnSite_max pvalues 0.122 True
# PumpSecondsOnSite_mean pvalues 0.169 PumpSecondsOnSite_max pvalues 0.619 False
# PumpSecondsOnSite_mean pvalues 0.062 PumpSecondsOnSite_max pvalues 0.341 False
# PumpSecondsOnSite_mean pvalues 0.046 PumpSecondsOnSite_max pvalues 0.008 True
# PumpSecondsOnSite_mean pvalues 0.151 PumpSecondsOnSite_max pvalues 0.568 False
# PumpSecondsOnSite_mean pvalues 0.181 PumpSecondsOnSite_max pvalues 0.659 False
# PumpSecondsOnSite_mean pvalues 0.081 PumpSecondsOnSite_max pvalues 0.417 False
# PumpSecondsOnSite_mean pvalues 0.027 PumpSecondsOnSite_max pvalues 0.122 True
# PumpSecondsOnSite_mean pvalues 0.062 PumpSecondsOnSite_max pvalues 0.019 True
# PumpSecondsOnSite_mean pvalues 0.351 PumpSecondsOnSite_max pvalues 0.873 False
# PumpSecondsOnSite_mean pvalues 0.139 PumpSecondsOnSite_max pvalues 0.485 False
# PumpSecondsOnSite_mean pvalues 0.106 PumpSecondsOnSite_max pvalues 0.6 False
# PumpSecondsOnSite_mean pvalues 0.125 PumpSecondsOnSite_max pvalues 0.675 False
# PumpSecondsOnSite_mean pvalues 0.098 PumpSecondsOnSite_max pvalues 0.567 False
# PumpSecondsOnSite_mean pvalues 0.377 PumpSecondsOnSite_max pvalues 0.767 False
# PumpSecondsOnSite_mean pvalues 0.1 PumpSecondsOnSite_max pvalues 0.002 True
# PumpSecondsOnSite_mean pvalues 0.186 PumpSecondsOnSite_max pvalues 0.902 False
# PumpSecondsOnSite_mean pvalues 0.163 PumpSecondsOnSite_max pvalues 0.457 False
# PumpSecondsOnSite_mean pvalues 0.086 PumpSecondsOnSite_max pvalues 0.0 True
# PumpSecondsOnSite_mean pvalues 0.113 PumpSecondsOnSite_max pvalues 0.476 False
# PumpSecondsOnSite_mean pvalues 0.223 PumpSecondsOnSite_max pvalues 0.021 True
# PumpSecondsOnSite_mean pvalues 0.394 PumpSecondsOnSite_max pvalues 0.729 False
# PumpSecondsOnSite_mean pvalues 0.118 PumpSecondsOnSite_max pvalues 0.674 False
# PumpSecondsOnSite_mean pvalues 0.066 PumpSecondsOnSite_max pvalues 0.523 False
# PumpSecondsOnSite_mean pvalues 0.054 PumpSecondsOnSite_max pvalues 0.312 False
# PumpSecondsOnSite_mean pvalues 0.172 PumpSecondsOnSite_max pvalues 0.542 False
# PumpSecondsOnSite_mean pvalues 0.102 PumpSecondsOnSite_max pvalues 0.014 True
# PumpSecondsOnSite_mean pvalues 0.153 PumpSecondsOnSite_max pvalues 0.795 False
# PumpSecondsOnSite_mean pvalues 0.122 PumpSecondsOnSite_max pvalues 0.659 False
# PumpSecondsOnSite_mean pvalues 0.01 PumpSecondsOnSite_max pvalues 0.058 True
# PumpSecondsOnSite_mean pvalues 0.163 PumpSecondsOnSite_max pvalues 0.021 True
# PumpSecondsOnSite_mean pvalues 0.065 PumpSecondsOnSite_max pvalues 0.378 False
# PumpSecondsOnSite_mean pvalues 0.24 PumpSecondsOnSite_max pvalues 0.026 True
# PumpSecondsOnSite_mean pvalues 0.6 PumpSecondsOnSite_max pvalues 0.005 True
# PumpSecondsOnSite_mean pvalues 0.305 PumpSecondsOnSite_max pvalues 0.885 False
# PumpSecondsOnSite_mean pvalues 0.034 PumpSecondsOnSite_max pvalues 0.078 True
# PumpSecondsOnSite_mean pvalues 0.045 PumpSecondsOnSite_max pvalues 0.077 True
# PumpSecondsOnSite_mean pvalues 0.278 PumpSecondsOnSite_max pvalues 0.006 True
# PumpSecondsOnSite_mean pvalues 0.084 PumpSecondsOnSite_max pvalues 0.394 False
# PumpSecondsOnSite_mean pvalues 0.081 PumpSecondsOnSite_max pvalues 0.598 False
# PumpSecondsOnSite_mean pvalues 0.018 PumpSecondsOnSite_max pvalues 0.002 True
# PumpSecondsOnSite_mean pvalues 0.096 PumpSecondsOnSite_max pvalues 0.439 False
# PumpSecondsOnSite_mean pvalues 0.04 PumpSecondsOnSite_max pvalues 0.252 True
# PumpSecondsOnSite_mean pvalues 0.239 PumpSecondsOnSite_max pvalues 0.745 False
# PumpSecondsOnSite_mean pvalues 0.23 PumpSecondsOnSite_max pvalues 0.721 False
# PumpSecondsOnSite_mean pvalues 0.043 PumpSecondsOnSite_max pvalues 0.015 True
# PumpSecondsOnSite_mean pvalues 0.014 PumpSecondsOnSite_max pvalues 0.14 True
# PumpSecondsOnSite_mean pvalues 0.314 PumpSecondsOnSite_max pvalues 0.597 False
# PumpSecondsOnSite_mean pvalues 0.209 PumpSecondsOnSite_max pvalues 0.984 False
# PumpSecondsOnSite_mean pvalues 0.118 PumpSecondsOnSite_max pvalues 0.655 False
# PumpSecondsOnSite_mean pvalues 0.035 PumpSecondsOnSite_max pvalues 0.291 True
# PumpSecondsOnSite_mean pvalues 0.112 PumpSecondsOnSite_max pvalues 0.03 True
# PumpSecondsOnSite_mean pvalues 0.059 PumpSecondsOnSite_max pvalues 0.011 True
# PumpSecondsOnSite_mean pvalues 0.11 PumpSecondsOnSite_max pvalues 0.637 False
# PumpSecondsOnSite_mean pvalues 0.026 PumpSecondsOnSite_max pvalues 0.173 True
# PumpSecondsOnSite_mean pvalues 0.118 PumpSecondsOnSite_max pvalues 0.661 False
# PumpSecondsOnSite_mean pvalues 0.048 PumpSecondsOnSite_max pvalues 0.152 True
# PumpSecondsOnSite_mean pvalues 0.15 PumpSecondsOnSite_max pvalues 0.824 False
# PumpSecondsOnSite_mean pvalues 0.227 PumpSecondsOnSite_max pvalues 0.787 False
# PumpSecondsOnSite_mean pvalues 0.118 PumpSecondsOnSite_max pvalues 0.019 True
# PumpSecondsOnSite_mean pvalues 0.023 PumpSecondsOnSite_max pvalues 0.086 True
# PumpSecondsOnSite_mean pvalues 0.166 PumpSecondsOnSite_max pvalues 0.607 False
# PumpSecondsOnSite_mean pvalues 0.051 PumpSecondsOnSite_max pvalues 0.0 True
# PumpSecondsOnSite_mean pvalues 0.055 PumpSecondsOnSite_max pvalues 0.0 True
# PumpSecondsOnSite_mean pvalues 0.027 PumpSecondsOnSite_max pvalues 0.054 True
# PumpSecondsOnSite_mean pvalues 0.08 PumpSecondsOnSite_max pvalues 0.013 True
# PumpSecondsOnSite_mean pvalues 0.211 PumpSecondsOnSite_max pvalues 0.687 False
# PumpSecondsOnSite_mean pvalues 0.005 PumpSecondsOnSite_max pvalues 0.059 True
# PumpSecondsOnSite_mean pvalues 0.11 PumpSecondsOnSite_max pvalues 0.586 False
#                                  PumpSecondsOnSite_min coefficients  \
# Postcode_district[T.KT22]                                  1421.200
# PropertyType[T.AIRFIELD/RUNWAY]                           -1064.185
# PropertyType[T.BARBECUE]                                   -948.195
# PropertyType[T.BARGE]                                      -170.091
# PropertyType[T.BEACH]                                      -816.967
#
#                                  PumpSecondsOnSite_min pvalues  \
# Postcode_district[T.KT22]                                0.036
# PropertyType[T.AIRFIELD/RUNWAY]                          0.007
# PropertyType[T.BARBECUE]                                 0.007
# PropertyType[T.BARGE]                                    0.635
# PropertyType[T.BEACH]                                    0.049
#
#                                  PumpSecondsOnSite_mean coefficients  \
# Postcode_district[T.KT22]                                   1246.963
# PropertyType[T.AIRFIELD/RUNWAY]                             -606.963
# PropertyType[T.BARBECUE]                                    -706.137
# PropertyType[T.BARGE]                                        418.967
# PropertyType[T.BEACH]                                       -445.139
#
#                                  PumpSecondsOnSite_mean pvalues  \
# Postcode_district[T.KT22]                                 0.079
# PropertyType[T.AIRFIELD/RUNWAY]                           0.142
# PropertyType[T.BARBECUE]                                  0.055
# PropertyType[T.BARGE]                                     0.263
# PropertyType[T.BEACH]                                     0.305
#
#                                  PumpSecondsOnSite_max coefficients  \
# Postcode_district[T.KT22]                                  1178.194
# PropertyType[T.AIRFIELD/RUNWAY]                             146.913
# PropertyType[T.BARBECUE]                                   -430.398
# PropertyType[T.BARGE]                                      1012.678
# PropertyType[T.BEACH]                                       -46.733
#
#                                  PumpSecondsOnSite_max pvalues  Discord   Keep
# Postcode_district[T.KT22]                                0.140     True  False
# PropertyType[T.AIRFIELD/RUNWAY]                          0.753     True  False
# PropertyType[T.BARBECUE]                                 0.298     True  False
# PropertyType[T.BARGE]                                    0.016     True   True
# PropertyType[T.BEACH]                                    0.924     True  False
# TurnoutTimeSeconds_mean pvalues 0.015 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.057 TurnoutTimeSeconds_max pvalues 0.026 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.048 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.055 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.035 TurnoutTimeSeconds_max pvalues 0.005 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.017 TurnoutTimeSeconds_max pvalues 0.006 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.027 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.003 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.079 TurnoutTimeSeconds_max pvalues 0.026 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.023 TurnoutTimeSeconds_max pvalues 0.018 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.013 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.092 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.107 TurnoutTimeSeconds_max pvalues 0.04 True
# TurnoutTimeSeconds_mean pvalues 0.065 TurnoutTimeSeconds_max pvalues 0.036 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.037 TurnoutTimeSeconds_max pvalues 0.45 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.007 TurnoutTimeSeconds_max pvalues 0.054 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.034 TurnoutTimeSeconds_max pvalues 0.03 True
# TurnoutTimeSeconds_mean pvalues 0.029 TurnoutTimeSeconds_max pvalues 0.027 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.2 TurnoutTimeSeconds_max pvalues 0.893 False
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.008 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.01 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.034 TurnoutTimeSeconds_max pvalues 0.015 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.029 TurnoutTimeSeconds_max pvalues 0.014 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.017 TurnoutTimeSeconds_max pvalues 0.362 True
# TurnoutTimeSeconds_mean pvalues 0.011 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.006 TurnoutTimeSeconds_max pvalues 0.002 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.037 TurnoutTimeSeconds_max pvalues 0.011 True
# TurnoutTimeSeconds_mean pvalues 0.123 TurnoutTimeSeconds_max pvalues 0.03 True
# TurnoutTimeSeconds_mean pvalues 0.008 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.012 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.017 TurnoutTimeSeconds_max pvalues 0.174 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.091 TurnoutTimeSeconds_max pvalues 0.009 True
# TurnoutTimeSeconds_mean pvalues 0.003 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.009 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.004 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.02 TurnoutTimeSeconds_max pvalues 0.012 True
# TurnoutTimeSeconds_mean pvalues 0.046 TurnoutTimeSeconds_max pvalues 0.02 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.057 TurnoutTimeSeconds_max pvalues 0.217 False
# TurnoutTimeSeconds_mean pvalues 0.019 TurnoutTimeSeconds_max pvalues 0.004 True
# TurnoutTimeSeconds_mean pvalues 0.027 TurnoutTimeSeconds_max pvalues 0.021 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.005 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.002 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.001 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.299 TurnoutTimeSeconds_max pvalues 0.433 False
# TurnoutTimeSeconds_mean pvalues 0.948 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.676 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.133 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.13 TurnoutTimeSeconds_max pvalues 0.956 False
# TurnoutTimeSeconds_mean pvalues 0.824 TurnoutTimeSeconds_max pvalues 0.0 True
# TurnoutTimeSeconds_mean pvalues 0.037 TurnoutTimeSeconds_max pvalues 0.001 True
# TurnoutTimeSeconds_mean pvalues 0.0 TurnoutTimeSeconds_max pvalues 0.117 True
#                                                     TurnoutTimeSeconds_min coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                 -9.466
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                              -18.430
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                              -17.759
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                -13.426
# PropertyType[T.ART GALLERY]                                                     -16.059
#
#                                                     TurnoutTimeSeconds_min pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                             0.372
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                           0.067
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                           0.250
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                             0.211
# PropertyType[T.ART GALLERY]                                                  0.108
#
#                                                     TurnoutTimeSeconds_mean coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                 -26.232
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                               -30.268
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                               -29.904
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                 -31.173
# PropertyType[T.ART GALLERY]                                                      -31.125
#
#                                                     TurnoutTimeSeconds_mean pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                              0.015
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                            0.003
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                            0.057
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                              0.004
# PropertyType[T.ART GALLERY]                                                   0.002
#
#                                                     TurnoutTimeSeconds_max coefficients  \
# PropertyType[T.AIRPORT - HANGAR]                                                -42.420
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                              -40.649
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                              -41.776
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                                -48.819
# PropertyType[T.ART GALLERY]                                                     -45.886
#
#                                                     TurnoutTimeSeconds_max pvalues  \
# PropertyType[T.AIRPORT - HANGAR]                                             0.001
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...                           0.001
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...                           0.026
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]                             0.000
# PropertyType[T.ART GALLERY]                                                  0.000
#
#                                                     Discord  Keep
# PropertyType[T.AIRPORT - HANGAR]                       True  True
# PropertyType[T.AIRPORT BUILDING (NOT TERMINAL O...     True  True
# PropertyType[T.ANIMAL BOARDING/BREEDING ESTABLI...     True  True
# PropertyType[T.ANIMAL PRODUCTS PROCESSING PLANT]       True  True
# PropertyType[T.ART GALLERY]                            True  True
# TravelTimeSeconds_mean pvalues 0.035 TravelTimeSeconds_max pvalues 0.039 True
# TravelTimeSeconds_mean pvalues 0.028 TravelTimeSeconds_max pvalues 0.026 True
# TravelTimeSeconds_mean pvalues 0.023 TravelTimeSeconds_max pvalues 0.028 True
# TravelTimeSeconds_mean pvalues 0.0 TravelTimeSeconds_max pvalues 0.056 True
# TravelTimeSeconds_mean pvalues 0.353 TravelTimeSeconds_max pvalues 0.022 True
# TravelTimeSeconds_mean pvalues 0.451 TravelTimeSeconds_max pvalues 0.0 True
#                            TravelTimeSeconds_min coefficients  \
# Postcode_district[T.BR2]                              -85.331
# Postcode_district[T.BR5]                              -86.223
# Postcode_district[T.BR6]                              -95.624
# Postcode_district[T.CM13]                             151.751
# Postcode_district[T.CM14]                             115.225
#
#                            TravelTimeSeconds_min pvalues  \
# Postcode_district[T.BR2]                           0.084
# Postcode_district[T.BR5]                           0.081
# Postcode_district[T.BR6]                           0.053
# Postcode_district[T.CM13]                          0.015
# Postcode_district[T.CM14]                          0.027
#
#                            TravelTimeSeconds_mean coefficients  \
# Postcode_district[T.BR2]                              -107.061
# Postcode_district[T.BR5]                              -112.040
# Postcode_district[T.BR6]                              -115.992
# Postcode_district[T.CM13]                              140.744
# Postcode_district[T.CM14]                               85.604
#
#                            TravelTimeSeconds_mean pvalues  \
# Postcode_district[T.BR2]                            0.035
# Postcode_district[T.BR5]                            0.028
# Postcode_district[T.BR6]                            0.023
# Postcode_district[T.CM13]                           0.029
# Postcode_district[T.CM14]                           0.110
#
#                            TravelTimeSeconds_max coefficients  \
# Postcode_district[T.BR2]                             -122.666
# Postcode_district[T.BR5]                             -132.425
# Postcode_district[T.BR6]                             -130.986
# Postcode_district[T.CM13]                             134.428
# Postcode_district[T.CM14]                              60.684
#
#                            TravelTimeSeconds_max pvalues  Discord   Keep
# Postcode_district[T.BR2]                           0.039     True   True
# Postcode_district[T.BR5]                           0.026     True   True
# Postcode_district[T.BR6]                           0.028     True   True
# Postcode_district[T.CM13]                          0.074     True   True
# Postcode_district[T.CM14]                          0.332     True  False
# PumpSecondsOnSite 90 discords, 87 keeps, sur 618, conserve 14.0%
# TurnoutTimeSeconds 142 discords, 288 keeps, sur 618, conserve 47.0%
# TravelTimeSeconds 149 discords, 432 keeps, sur 618, conserve 70.0%
#                            Keep             Column Value
# Postcode_district[T.BR1]  False  Postcode_district   BR1
# Postcode_district[T.BR2]  False  Postcode_district   BR2
# Postcode_district[T.BR3]  False  Postcode_district   BR3
# Postcode_district[T.BR4]  False  Postcode_district   BR4
# Postcode_district[T.BR5]  False  Postcode_district   BR5
# keep PumpSecondsOnSite
#                            Keep             Column Value
# Postcode_district[T.BR1]  False  Postcode_district   BR1
# Postcode_district[T.BR2]  False  Postcode_district   BR2
# Postcode_district[T.BR3]  False  Postcode_district   BR3
# Postcode_district[T.BR4]  False  Postcode_district   BR4
# Postcode_district[T.BR5]  False  Postcode_district   BR5
# keep TurnoutTimeSeconds
#                            Keep             Column Value
# Postcode_district[T.BR1]   True  Postcode_district   BR1
# Postcode_district[T.BR2]   True  Postcode_district   BR2
# Postcode_district[T.BR3]   True  Postcode_district   BR3
# Postcode_district[T.BR4]  False  Postcode_district   BR4
# Postcode_district[T.BR5]   True  Postcode_district   BR5
# keep TravelTimeSeconds
